# %% [markdown]
# # Adaboost [classifier + regressor] from scratch

# %%
# Regression Implementation yet to be added

# %% [markdown]
# ## Import statements

# %%
import numpy as np
import pandas as pd
from pprint import pprint

# %% [markdown]
# ## Load and prepare data

# %%
df = pd.read_csv("Iris.csv")
df = df.drop("Id", axis=1)
df = df.rename(columns={"species": "label"})

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        label
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Types of lables
df['label'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# Frequency plot
df['label'].value_counts().plot(kind='bar')

# %% [markdown]
# ## Helper functions

# %%
def train_test_split(df, test_size=0.8, random_state=None):
    train_df = df.sample(frac=test_size, random_state=random_state)
    test_df = df[~df.index.isin(train_df.index)]
    return train_df.sort_index(), test_df.sort_index()

# %%
def accuracy_score_classification(y_true, y_pred):
    accuracy = np.sum(y_true == y_pred, axis=0) / len(y_true)
    return accuracy

# %%
def accuracy_score_regression(y_true, y_pred):
    rmse = np.sqrt(np.sum((y_true - y_pred)**2) / len(y_true)) # RMSE
    return rmse

# %% [markdown]
# ## Algorithm Classes

# %% [markdown]
# - DecisionStump()
# - BaseBoostingAlgorithm()
# - AdaBoostClassifier()
# - AdaBoostRegressor()

# %%
class DecisionStump():
    def __init__(self):
        # Feature/Attribute Index to consider for splitting
        self.decision_feature_index = None
        # Exact value from Feature/Attribute to split on
        self.decision_threshold_value = None
        # Stump importance / weight
        self.weight = None
        # Stump error
        self.error = None
        # Left leaf value
        self.left_leaf_value = None
        # Right leaf value
        self.right_leaf_value = None
        # Stump decision compartor 
        self.decision_comparator = None
        print("New Stump Created!")

# %%
class BaseBoostingAlgorithm():
    def __init__(self, n_learners):
        self.n_learners = n_learners
        
    def fit(self, X, y):
        # Store all weak learners (Weak learner -> A decsion stump)
        self.learners = []
        # Identify each feature type in input X and store as list
        self.feature_types = self._determine_type_of_feature(X)
        # Concatenate input and output
        self.data = np.concatenate((X, np.expand_dims(y, axis=1)), axis=1)
        # Initialize weight for each example as 1/N (where N -> total number of examples)
        self.sample_weight = np.full(len(self.data), np.divide(1, len(self.data)))        
        print(self.feature_types)
        print(self.ml_task)
        
        # Iterate and build learners
        for i_boost in range(self.n_learners):
            # Instantiate a new decision stump object
            learner = DecisionStump()
            # Find and Perform split over best feature 
            potential_splits = self._get_potential_splits(self.data)
            
            split_column_index, split_value, metric = self._determine_best_split(self.data, self.sample_weight, potential_splits, self.ml_task)
            left_node_data, right_node_data = self._split_data(self.data, split_column_index, split_value)
            print(f'split_column_index: {split_column_index}, split_value: {split_value}')
            print(f'Change in overall_metric: {metric}')
            # Compute Leaf values
            left_leaf_value = self._create_leaf(left_node_data, self.ml_task)
            right_leaf_value = self._create_leaf(right_node_data, self.ml_task)
            print(f'Left leaf: {left_leaf_value}, Right leaf: {right_leaf_value}')

            # Allocate the instantiated learner with our computed values
            learner.decision_feature_index = split_column_index
            learner.decision_threshold_value = split_value
            learner.left_leaf_value = left_leaf_value
            learner.right_leaf_value = right_leaf_value
            learner.decision_comparator = self.feature_types[split_column_index]
            
            # Boosting step
            self.sample_weight, learner = self.boost(i_boost,
                                              self.data,
                                              self.sample_weight,
                                              learner)
            # Early Termination
            if self.sample_weight is None:
                break
            # Stop boosting since error is 0
            # Stop if the sum of sample weights has become non-positive
            if learner.error == 0 or np.sum(self.sample_weight) <= 0:
                self.learners.append(learner)
                break
            print(f'{i_boost}: Sample weight(sum) {np.sum(self.sample_weight)}')
            # Dont perform operations in below conditional block if we are on final learner
            if not i_boost == self.n_learners - 1:
                # Normalize
                self.sample_weight /= np.sum(self.sample_weight)
                # Construct new data set sample based on sample_weight
#                 self.data = self._sample_data_by_weights(self.data, self.sample_weight)
                # Reinitialize equal sample weights for the new data
#                 self.sample_weight = np.full(len(self.data), (1 / len(self.data)))
            
            # Add this learner to our main list of learners
            self.learners.append(learner)
            print(f'Total stumps: {len(self.learners)}')
            
        return self  
            
    def stump_predict(self, data, learner):
        """
        Computes prediction for the passed data examples w.r.t to the learner(descision stump) 
        """
        preds = []
        feature_column = data[:, learner.decision_feature_index]
        for value in feature_column:
            if learner.decision_comparator == 'categorical':
                if value == learner.decision_threshold_value: # Left node
                    pred = learner.left_leaf_value
                else: # right node
                    pred = learner.right_leaf_value
            else: # continuous
                if value <= learner.decision_threshold_value: # Left node
                    pred = learner.left_leaf_value
                else: # right node
                    pred = learner.right_leaf_value
            preds.append(pred)
        return preds
    
    def _fast_gini(self, data):
        label_column = data[:, -2]
        data_sample_weight =  data[:, -1]
        _, value_indexes, counts = np.unique(label_column, return_counts=True, return_index=True)
        # Get summed weights for each class
        class_weights = np.array([np.take(data_sample_weight, np.where(label_column == label_column[value_index])[0]).sum() for value_index in value_indexes])
        
        weighted_classes = counts * class_weights
        normalized_weighted_classes = weighted_classes / sum(weighted_classes)
        #return 1.0 - (np.sum(counts**2) / np.sum(class_weights)**2)
        return 1.0 - sum(normalized_weighted_classes**2)
    
    
    def _calculate_weighted_mse(self, data):
        """
        Calculate weighted mean squared error
        """
        actual_values = data[:, -2]
        data_sample_weight =  data[:, -1]
        
        if len(actual_values) == 0:   # empty data
            mse = 0

        else:
            prediction = np.mean(actual_values)
            # Not normalizing using sum of weighted mean, beacuse the sum of weighted mean is 1
            weighted_mse = np.mean((data_sample_weight * (actual_values - prediction))**2)

        return weighted_mse
    
    
    def _calculate_weighted_gini_index(self, data):
        """
        Calculate weighted gini index
        """
        label_column = data[:, -2]
        data_sample_weight =  data[:, -1]
        #_, counts = np.unique(label_column, return_counts=True)
        _, value_indexes, counts = np.unique(label_column, return_counts=True, return_index=True)
        # Get summed weights for each class
        class_weights = np.array([np.take(data_sample_weight, np.where(label_column == label_column[value_index])[0]).sum() for value_index in value_indexes])
    
        weighted_classes = counts * class_weights
        normalized_weighted_classes = weighted_classes / sum(weighted_classes)
        
        #class_counts_squared = np.sum(counts**2)
        #class_weights_squared = np.sum(class_weights)**2
        
        weighted_gini_impurity = (1 - sum(normalized_weighted_classes**2))
        #print(f'class_weights_squared: {class_weights_squared}')
        #weighted_gini_impurity = 1.0 - np.divide(class_counts_squared, class_weights_squared)
        return weighted_gini_impurity
    
    def _calculate_weighted_overall_metric(self, data, left_node_data, right_node_data, metric_function):
        """
        Generalized impurity metric, computes weighted overall
        impurity/error w.r.t left and right nodes
        """
        # Labels
        left_label_column = left_node_data[:, -2]
        right_label_column = right_node_data[:, -2]
        parent_label_column = data[:, -2]
        # Sample weights
        left_sample_weight = left_node_data[:, -1]
        right_sample_weight = right_node_data[:, -1]
        parent_sample_weight = data[:, -1]
        
        if self.ml_task == 'classification':
            _, left_value_indexes, left_counts = np.unique(left_label_column, return_counts=True, return_index=True)
            _, right_value_indexes, right_counts = np.unique(right_label_column, return_counts=True, return_index=True)
            _, parent_value_indexes, parent_counts = np.unique(parent_label_column, return_counts=True, return_index=True)
            
            left_class_weights = np.array([np.take(left_sample_weight, np.where(left_label_column == left_label_column[value_index])[0]).sum() for value_index in left_value_indexes])
            right_class_weights = np.array([np.take(right_sample_weight, np.where(right_label_column == right_label_column[value_index])[0]).sum() for value_index in right_value_indexes])
            parent_class_weights = np.array([np.take(parent_sample_weight, np.where(parent_label_column == parent_label_column[value_index])[0]).sum() for value_index in parent_value_indexes])
            
            # class count * class weight, for respective classes
            left_weighted_classes = left_counts * left_class_weights
            right_weighted_classes = right_counts * right_class_weights
            parent_weighted_classes = parent_counts * parent_class_weights
            
#             weighted_prob_node_left = np.divide(np.sum(left_weighted_classes), np.sum(parent_weighted_classes))
#             weighted_prob_node_right = np.divide(np.sum(right_weighted_classes), np.sum(parent_weighted_classes))
            
            #weighted_prob_node_left = np.sum(left_weighted_classes / np.sum(parent_class_weights))
            #weighted_prob_node_right = np.sum(right_weighted_classes / np.sum(parent_class_weights))
            
            weighted_prob_node_left = np.sum(left_class_weights)# / np.sum(parent_weighted_classes)
            weighted_prob_node_right = np.sum(right_class_weights)# / np.sum(parent_weighted_classes)
            
        else:
            total_parent_sample_weight = np.sum(np.sum(left_sample_weight), np.sum(right_sample_weight))
            # Weighted probabilities of left and right node
            weighted_prob_node_left = np.sum(left_sample_weight) / total_parent_sample_weight
            weighted_prob_node_right = np.sum(right_sample_weight) / total_parent_sample_weight
        
        overall_metric =  weighted_prob_node_left * metric_function(left_node_data) + weighted_prob_node_right * metric_function(right_node_data)
        
        # Compute final overall metric
        #print(f'Left gini: {metric_function(left_node_data)}, Right gini: {metric_function(right_node_data)}')
        #overall_metric = (weighted_prob_node_left * metric_function(left_node_data)) + (weighted_prob_node_right * metric_function(right_node_data))
        #print(f'weighted_prob_node_left * w_i(left_node_data)): {weighted_prob_node_left} * {metric_function(left_node_data)} = {(weighted_prob_node_left * metric_function(left_node_data))}')
        #print(f'weighted_prob_node_right * w_i(right_node_data)): {weighted_prob_node_right} * {metric_function(right_node_data)} = {(weighted_prob_node_right * metric_function(right_node_data))}')
        return overall_metric

    
    def _sample_data_by_weights(self, data, sample_weight):
        """
        Construct an new input, iteratively sampled over distribution 
        formed by passed sample_weight.

        Note: 
        Learn more about this technique: https://youtu.be/LsK-xG1cLYA (Statquest)
        """
        n_samples, _ = np.shape(data)
        # Intialize array to hold sampled index  
        sampled_indices = []
        # Perform cumulative summation over sample_weight to create buckets
        sample_weight_buckets = np.cumsum(sample_weight)
        # Keeping sampling 'n_samples' times
        for _ in range(n_samples):
            # Generate a random number between 0 and 1
            random_num = np.random.random_sample()
            # Find the bucket Eg: weight buckets [0.33, 0.66, 0.99] and random number = 0.47
            # then index 1 will be selected (since cumsum value is 0.66)
            bucket_index = np.where(sample_weight_buckets > random_num)[0][0]

            sampled_indices.append(bucket_index)
        # finally construct weighted data using sampled_indexes
        weighted_data = data[sampled_indices]

        return weighted_data


    def _get_potential_splits(self, data):
        """
        Get all potential splits for each feature
        Splits can be made on each unique value
        Can essentially make a split at each unique value
        
        """
        potential_splits = {}
        _, n_columns = data.shape
        for column_index in range(n_columns - 1): # excluding the last column which is the label
            values = data[:, column_index]
            unique_values = np.unique(values)

            potential_splits[column_index] = unique_values
            
        return potential_splits
    
    
    def _calculate_overall_metric(self, left_node_data, right_node_data, metric_function):
        """
        Generalized impurity metric, computes weighted overall
        impurity/error w.r.t left and right nodes
        """
        n = len(left_node_data) + len(right_node_data)
        # Probabilities of left and right node
        prob_node_left = len(left_node_data) / n
        prob_node_right = len(right_node_data) / n

        overall_metric =  (prob_node_left * metric_function(left_node_data) 
                         + prob_node_right * metric_function(right_node_data))

        return overall_metric
    
    def _determine_best_split(self, data, sample_weight, potential_splits, ml_task):
        """
        Iterate over each column_index (as keys) in potential_split (dict)
        Perform split(of examples) over each unique value and evaluate the split
        Identify the best split and return its feature index and value
        """
        # Stitch data with sample_weight towards the end
        data = np.concatenate((data, np.expand_dims(sample_weight, axis=1)), axis=1)
        
        # Best minimum gini index to be updated iteratively
        best_overall_metric = float('inf')
        
        for column_index in potential_splits:
            #print(f"COLUMN {column_index}")
            for value in potential_splits[column_index]:
                print(f'column_index: {column_index}, value: {value}')
                left_node_data, right_node_data = self._split_data(data, split_column_index=column_index, split_value=value)

                if ml_task == "regression":
                    current_overall_metric = self._calculate_weighted_overall_metric(data, left_node_data, right_node_data,
                                                                                     metric_function=self._calculate_weighted_mse)
                else: # classification
                    current_overall_metric = self._calculate_weighted_overall_metric(data, left_node_data, right_node_data,
                                                                                     metric_function=self._fast_gini)

                # If a lower overall_metric is achieved update the index and value with the current
                if current_overall_metric < best_overall_metric:
                    best_overall_metric = current_overall_metric
                    best_split_column_index = column_index
                    best_split_value = value
                #print(f'best_overall_metric: {best_overall_metric}')
                #print('---')
            #print(f'Debug [1]: Best: {best_overall_metric}, index: {best_split_column_index}, value: {best_split_value}')
        return best_split_column_index, best_split_value, best_overall_metric
    
    
    def _split_data(self, data, split_column_index, split_value):
        """ 
        Split data(examples) based on best split_column_index and split_value
        estimated using task specific splitting metric.
        """
        # Get values(from feature column) for the passed split_column index
        split_column_values = data[:, split_column_index]

        type_of_feature = self.feature_types[split_column_index]
        if type_of_feature == "continuous":
            left_node_data = data[split_column_values <= split_value]
            right_node_data = data[split_column_values >  split_value]

        # feature is categorical   
        else:
            left_node_data = data[split_column_values == split_value]
            right_node_data = data[split_column_values != split_value]
        return left_node_data, right_node_data
    
    
    def _create_leaf(self, data, ml_task):
        """
        Create leaf node, with leaf value based on ml_task
        for,
        Classfication: consider majority vote
        Regression: consider the mean value
        """
        label_column = data[:, -1]
        if ml_task == "regression":
            leaf = np.mean(label_column)

        # classfication    
        else:
            unique_classes, counts_unique_classes = np.unique(label_column, return_counts=True)
            index = counts_unique_classes.argmax()
            leaf = unique_classes[index]

        return leaf
    
    
    def _determine_type_of_feature(self, X):
        """
        Determine, if the feature is categorical or continuous
        """
        feature_types = []
        n_unique_values_treshold = 15 # Threshold for a numeric feature to be categorical
        
        n_samples, n_features = np.shape(X)
        
        for feature_i in range(n_features):
            unique_values = np.unique(X[:, feature_i])
            example_value = unique_values[0]

            if (isinstance(example_value, str)) or (len(unique_values) <= n_unique_values_treshold):
                feature_types.append("categorical")
            else:
                feature_types.append("continuous")

        return feature_types

# %%
class AdaBoostClassifier(BaseBoostingAlgorithm):
    def __init__(self, n_learners=20):
        # Set total number of weak learners
        super().__init__(n_learners)
        self.ml_task = "classification"
        self.classes = None
        self.n_classes = None
        
    def boost(self, i_boost, data, sample_weight, learner):
        """
        Compute learner importance and error, along with boosted weights for each example 
        """
        print(f'Boost Called')
        
        # If its first boost initialize number of classes(n_classes)
        if i_boost == 0:
            self.classes = np.unique(data[:, -1])
            self.n_classes = self.classes.size
            
        # Perform predictions
        preds = self.stump_predict(data, learner)
        
        # Incorrectly classified examples
        incorrect = preds != data[:, -1]

        # Learner Error
        learner_error = np.mean(np.average(incorrect, weights=sample_weight, axis=0))
        # Stop if classification is perfect
        if learner_error <= 0:
            learner.weight = 1
            learner.error = 0
            return sample_weight, learner
        print(f'Learner error: {learner_error}')
        
        # Learner weight
        learner_weight = (np.log((1 - learner_error) / (learner_error)) +
                        np.log(self.n_classes - 1))
        print(f'Learner weight: {learner_weight}')
        
        # Boost sample_weight for each each sample
        # Dont boost sample_weight if we are on final learner
        if not i_boost == self.n_learners - 1:
        # Boost only positive weights
            sample_weight *= np.exp(learner_weight * incorrect *
                                    ((sample_weight > 0) | (learner_weight < 0)))

        # Allocate learner its computed weight and error
        learner.weight = learner_weight
        learner.error = learner_error

        # Finally return sample weights and boosted learner
        return sample_weight, learner
         
    def predict(self, X):
        """
        Predict classes for X.
        """
        print(f'Predict called')
        
        # Get activated matrix for with respect to each learner [get vote of each learner]
        # Add each activated matrix (matrix addition) [get overall vote of all leaners]
        # return the overall matrix
        # Argmax is used over each row of overall matrix to figure our the class
        classes = self.classes[:, np.newaxis]
        pred = sum((self.stump_predict(X, learner) == classes).T * learner.weight
                   for learner in self.learners)
        # Normalize 
        learner_weights = sum(learner.weight for learner in self.learners)
        pred /= learner_weights
        
        # If its binary classification obatin the form [-, +], convienient to select classes with np.take() 
        # Eg(binary): classes =  [[c1], [c2]] and pred = [True, False, True], below output: [[c2], [c1], [c2]]
        if self.n_classes == 2:
            pred[:, 0] *= -1
            pred = pred.sum(axis=1)
            return classes.take(pred > 0, axis=0)
        # Finds index of column with max value, and uses this index to select class from classes

        return classes.take(np.argmax(pred, axis=1), axis=0)

# %%
clf = AdaBoostClassifier(4)

# %%
clf = clf.fit(df.iloc[:, :-1].values, df.iloc[:, -1].values)
# Out:
# ['continuous', 'continuous', 'continuous', 'continuous']
# classification
# New Stump Created!
# column_index: 0, value: 4.3
# weighted_prob_node_left * w_i(left_node_data)): 0.006666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9933333333333323 * 0.6665473782369379 = 0.662103729048691
# column_index: 0, value: 4.4
# weighted_prob_node_left * w_i(left_node_data)): 0.02666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9733333333333323 * 0.66472533691266 = 0.6469993279283217
# column_index: 0, value: 4.5
# weighted_prob_node_left * w_i(left_node_data)): 0.03333333333333333 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9666666666666657 * 0.6636187484960929 = 0.6414981235462225
# column_index: 0, value: 4.6
# weighted_prob_node_left * w_i(left_node_data)): 0.060000000000000005 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9399999999999991 * 0.6566483766233984 = 0.6172494740259938
# column_index: 0, value: 4.7
# weighted_prob_node_left * w_i(left_node_data)): 0.07333333333333333 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9266666666666659 * 0.6516405857183571 = 0.6038536094323438
# column_index: 0, value: 4.8
# weighted_prob_node_left * w_i(left_node_data)): 0.10666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.8933333333333324 * 0.6348898743139706 = 0.5671682877204798
# column_index: 0, value: 4.9
# weighted_prob_node_left * w_i(left_node_data)): 0.14666666666666664 * 0.009913120962352528 = 0.001453924407811704
# weighted_prob_node_right * w_i(right_node_data)): 0.8533333333333325 * 0.6204694618157204 = 0.5294672740827475
# column_index: 0, value: 5.0
# weighted_prob_node_left * w_i(left_node_data)): 0.2133333333333332 * 0.024900227778870354 = 0.005312048592825672
# weighted_prob_node_right * w_i(right_node_data)): 0.786666666666666 * 0.5807620041222659 = 0.4568661099095154
# column_index: 0, value: 5.1
# weighted_prob_node_left * w_i(left_node_data)): 0.2733333333333331 * 0.025578186150678972 = 0.00699137088118558
# weighted_prob_node_right * w_i(right_node_data)): 0.726666666666666 * 0.5371644960517268 = 0.3903395337975878
# column_index: 0, value: 5.2
# weighted_prob_node_left * w_i(left_node_data)): 0.29999999999999977 * 0.03306940597331853 = 0.009920821791995552
# weighted_prob_node_right * w_i(right_node_data)): 0.6999999999999994 * 0.5221297642021419 = 0.365490834941499
# column_index: 0, value: 5.3
# weighted_prob_node_left * w_i(left_node_data)): 0.3066666666666664 * 0.03148786100407108 = 0.00965627737458179
# weighted_prob_node_right * w_i(right_node_data)): 0.6933333333333327 * 0.5179115354326326 = 0.35908533123329156
# column_index: 0, value: 5.4
# weighted_prob_node_left * w_i(left_node_data)): 0.34666666666666635 * 0.03526046581201003 = 0.012223628148163466
# weighted_prob_node_right * w_i(right_node_data)): 0.6533333333333327 * 0.5 = 0.3266666666666663
# column_index: 0, value: 5.5
# weighted_prob_node_left * w_i(left_node_data)): 0.39333333333333304 * 0.09924209924209926 = 0.03903522570189234
# weighted_prob_node_right * w_i(right_node_data)): 0.6066666666666661 * 0.4772246202474757 = 0.28951626961680166
# column_index: 0, value: 5.6
# weighted_prob_node_left * w_i(left_node_data)): 0.433333333333333 * 0.1887689242106374 = 0.08179986715794281
# weighted_prob_node_right * w_i(right_node_data)): 0.5666666666666662 * 0.4478266133652916 = 0.2537684142403317
# column_index: 0, value: 5.7
# weighted_prob_node_left * w_i(left_node_data)): 0.48666666666666636 * 0.2668287853609921 = 0.1298566755423494
# weighted_prob_node_right * w_i(right_node_data)): 0.5133333333333329 * 0.3998063726224812 = 0.20523393794620684
# column_index: 0, value: 5.8
# weighted_prob_node_left * w_i(left_node_data)): 0.533333333333333 * 0.3202496679244785 = 0.1707998228930551
# weighted_prob_node_right * w_i(right_node_data)): 0.46666666666666634 * 0.3836504388978659 = 0.17903687148567063
# column_index: 0, value: 5.9
# weighted_prob_node_left * w_i(left_node_data)): 0.5533333333333329 * 0.35490636380025264 = 0.1963815213028063
# weighted_prob_node_right * w_i(right_node_data)): 0.4466666666666663 * 0.36221456052715484 = 0.1617891703687957
# column_index: 0, value: 6.0
# weighted_prob_node_left * w_i(left_node_data)): 0.5933333333333329 * 0.4168234320987878 = 0.24731523637861394
# weighted_prob_node_right * w_i(right_node_data)): 0.4066666666666664 * 0.31053713364157676 = 0.12628510101424112
# column_index: 0, value: 6.1
# weighted_prob_node_left * w_i(left_node_data)): 0.6333333333333329 * 0.46718621950550177 = 0.29588460568681757
# weighted_prob_node_right * w_i(right_node_data)): 0.3666666666666665 * 0.24661774332122888 = 0.09042650588445054
# column_index: 0, value: 6.2
# weighted_prob_node_left * w_i(left_node_data)): 0.6599999999999995 * 0.49379409047322975 = 0.32590409971233136
# weighted_prob_node_right * w_i(right_node_data)): 0.3399999999999998 * 0.21910931008788515 = 0.07449716542988091
# column_index: 0, value: 6.3
# weighted_prob_node_left * w_i(left_node_data)): 0.7199999999999995 * 0.5472452656306734 = 0.3940165912540846
# weighted_prob_node_right * w_i(right_node_data)): 0.27999999999999986 * 0.1986480160994395 = 0.05562144450784303
# column_index: 0, value: 6.4
# weighted_prob_node_left * w_i(left_node_data)): 0.7666666666666659 * 0.5842716589636623 = 0.447941605205474
# weighted_prob_node_right * w_i(right_node_data)): 0.23333333333333325 * 0.19110407661473983 = 0.04459095121010594
# column_index: 0, value: 6.5
# weighted_prob_node_left * w_i(left_node_data)): 0.7999999999999993 * 0.6084988233403072 = 0.4867990586722454
# weighted_prob_node_right * w_i(right_node_data)): 0.19999999999999998 * 0.20629761841334138 = 0.041259523682668275
# column_index: 0, value: 6.6
# weighted_prob_node_left * w_i(left_node_data)): 0.8133333333333326 * 0.6105183423613865 = 0.4965549184539272
# weighted_prob_node_right * w_i(right_node_data)): 0.18666666666666665 * 0.12887573964497046 = 0.024056804733727816
# column_index: 0, value: 6.7
# weighted_prob_node_left * w_i(left_node_data)): 0.8666666666666659 * 0.633647446080835 = 0.5491611199367232
# weighted_prob_node_right * w_i(right_node_data)): 0.13333333333333333 * 0.058578442412503984 = 0.0078104589883338646
# column_index: 0, value: 6.8
# weighted_prob_node_left * w_i(left_node_data)): 0.8866666666666658 * 0.6407301954964671 = 0.5681141066735337
# weighted_prob_node_right * w_i(right_node_data)): 0.11333333333333334 * 0.03432428824774503 = 0.0038900860014111035
# column_index: 0, value: 6.9
# weighted_prob_node_left * w_i(left_node_data)): 0.9133333333333324 * 0.6497695361474849 = 0.5934561763480356
# weighted_prob_node_right * w_i(right_node_data)): 0.08666666666666667 * 0.013697978596908467 = 0.0011871581450654005
# column_index: 0, value: 7.0
# weighted_prob_node_left * w_i(left_node_data)): 0.919999999999999 * 0.6487636789437607 = 0.5968625846282593
# weighted_prob_node_right * w_i(right_node_data)): 0.08 * 0.0 = 0.0
# column_index: 0, value: 7.1
# weighted_prob_node_left * w_i(left_node_data)): 0.9266666666666658 * 0.6516405857183571 = 0.6038536094323437
# weighted_prob_node_right * w_i(right_node_data)): 0.07333333333333333 * 0.0 = 0.0
# column_index: 0, value: 7.2
# weighted_prob_node_left * w_i(left_node_data)): 0.9466666666666657 * 0.658773392794007 = 0.6236388118449927
# weighted_prob_node_right * w_i(right_node_data)): 0.05333333333333334 * 0.0 = 0.0
# column_index: 0, value: 7.3
# weighted_prob_node_left * w_i(left_node_data)): 0.9533333333333324 * 0.6606436178149171 = 0.629813582316887
# weighted_prob_node_right * w_i(right_node_data)): 0.04666666666666667 * 0.0 = 0.0
# column_index: 0, value: 7.4
# weighted_prob_node_left * w_i(left_node_data)): 0.9599999999999991 * 0.6622585936471067 = 0.6357682499012218
# weighted_prob_node_right * w_i(right_node_data)): 0.04 * 0.0 = 0.0
# column_index: 0, value: 7.6
# weighted_prob_node_left * w_i(left_node_data)): 0.9666666666666657 * 0.6636187484960929 = 0.6414981235462225
# weighted_prob_node_right * w_i(right_node_data)): 0.03333333333333333 * 0.0 = 0.0
# column_index: 0, value: 7.7
# weighted_prob_node_left * w_i(left_node_data)): 0.9933333333333323 * 0.6665473782369378 = 0.6621037290486909
# weighted_prob_node_right * w_i(right_node_data)): 0.006666666666666667 * 0.0 = 0.0
# column_index: 0, value: 7.9
# weighted_prob_node_left * w_i(left_node_data)): 0.9999999999999989 * 0.6666666666666667 = 0.666666666666666
# weighted_prob_node_right * w_i(right_node_data)): 0.0 * 1.0 = 0.0
# column_index: 1, value: 2.0
# weighted_prob_node_left * w_i(left_node_data)): 0.006666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9933333333333323 * 0.6665473782369379 = 0.662103729048691
# column_index: 1, value: 2.2
# weighted_prob_node_left * w_i(left_node_data)): 0.02666666666666667 * 0.17999999999999994 = 0.004799999999999999
# weighted_prob_node_right * w_i(right_node_data)): 0.9733333333333324 * 0.6658005898864735 = 0.6480459074895002
# column_index: 1, value: 2.3
# weighted_prob_node_left * w_i(left_node_data)): 0.05333333333333334 * 0.10110803324099704 = 0.005392428439519843
# weighted_prob_node_right * w_i(right_node_data)): 0.9466666666666658 * 0.6634916015728765 = 0.6281053828223224
# column_index: 1, value: 2.4
# weighted_prob_node_left * w_i(left_node_data)): 0.07333333333333333 * 0.04732181739004249 = 0.003470266608603116
# weighted_prob_node_right * w_i(right_node_data)): 0.9266666666666658 * 0.6584438294923334 = 0.610157948662895
# column_index: 1, value: 2.5
# weighted_prob_node_left * w_i(left_node_data)): 0.12666666666666668 * 0.23242603550295848 = 0.029440631163708077
# weighted_prob_node_right * w_i(right_node_data)): 0.8733333333333325 * 0.6504205151416569 = 0.5680339165570465
# column_index: 1, value: 2.6
# weighted_prob_node_left * w_i(left_node_data)): 0.16 * 0.27444572600281936 = 0.043911316160451096
# weighted_prob_node_right * w_i(right_node_data)): 0.8399999999999992 * 0.6400343187554585 = 0.5376288277545846
# column_index: 1, value: 2.7
# weighted_prob_node_left * w_i(left_node_data)): 0.21999999999999997 * 0.340241474718348 = 0.07485312443803654
# weighted_prob_node_right * w_i(right_node_data)): 0.7799999999999994 * 0.6127365973514524 = 0.4779345459341324
# column_index: 1, value: 2.8
# weighted_prob_node_left * w_i(left_node_data)): 0.31333333333333324 * 0.44402792281822545 = 0.1391287491497106
# weighted_prob_node_right * w_i(right_node_data)): 0.6866666666666662 * 0.5397478355345067 = 0.37062684706702764
# column_index: 1, value: 2.9
# weighted_prob_node_left * w_i(left_node_data)): 0.3799999999999998 * 0.4027651362495568 = 0.1530507517748315
# weighted_prob_node_right * w_i(right_node_data)): 0.6199999999999996 * 0.47425109155072365 = 0.29403567676144843
# column_index: 1, value: 3.0
# weighted_prob_node_left * w_i(left_node_data)): 0.5533333333333329 * 0.4944448094222408 = 0.273592794546973
# weighted_prob_node_right * w_i(right_node_data)): 0.44666666666666643 * 0.28613676674128896 = 0.127807755811109
# column_index: 1, value: 3.1
# weighted_prob_node_left * w_i(left_node_data)): 0.6333333333333329 * 0.5271081796261181 = 0.33383518042987453
# weighted_prob_node_right * w_i(right_node_data)): 0.3666666666666665 * 0.22088778040163437 = 0.08099218614726589
# column_index: 1, value: 3.2
# weighted_prob_node_left * w_i(left_node_data)): 0.7199999999999994 * 0.5580489115829077 = 0.40179521633969323
# weighted_prob_node_right * w_i(right_node_data)): 0.27999999999999986 * 0.11721611721611713 = 0.03282051282051278
# column_index: 1, value: 3.3
# weighted_prob_node_left * w_i(left_node_data)): 0.7599999999999993 * 0.5695445601417519 = 0.4328538657077311
# weighted_prob_node_right * w_i(right_node_data)): 0.23999999999999985 * 0.054637097714688276 = 0.013112903451525179
# column_index: 1, value: 3.4
# weighted_prob_node_left * w_i(left_node_data)): 0.8399999999999992 * 0.6157142439737034 = 0.5171999649379104
# weighted_prob_node_right * w_i(right_node_data)): 0.15999999999999998 * 0.039200000000000124 = 0.006272000000000019
# column_index: 1, value: 3.5
# weighted_prob_node_left * w_i(left_node_data)): 0.8799999999999991 * 0.6413103968391095 = 0.5643531492184158
# weighted_prob_node_right * w_i(right_node_data)): 0.12000000000000001 * 0.07396449704142039 = 0.008875739644970447
# column_index: 1, value: 3.6
# weighted_prob_node_left * w_i(left_node_data)): 0.899999999999999 * 0.647493779773746 = 0.5827444017963708
# weighted_prob_node_right * w_i(right_node_data)): 0.1 * 0.045173577466671055 = 0.004517357746667105
# column_index: 1, value: 3.7
# weighted_prob_node_left * w_i(left_node_data)): 0.919999999999999 * 0.655742565643506 = 0.6032831603920249
# weighted_prob_node_right * w_i(right_node_data)): 0.08 * 0.07396449704142016 = 0.005917159763313613
# column_index: 1, value: 3.8
# weighted_prob_node_left * w_i(left_node_data)): 0.9599999999999991 * 0.6622585936471067 = 0.6357682499012218
# weighted_prob_node_right * w_i(right_node_data)): 0.04 * 0.0 = 0.0
# column_index: 1, value: 3.9
# weighted_prob_node_left * w_i(left_node_data)): 0.9733333333333323 * 0.66472533691266 = 0.6469993279283217
# weighted_prob_node_right * w_i(right_node_data)): 0.02666666666666667 * 0.0 = 0.0
# column_index: 1, value: 4.0
# weighted_prob_node_left * w_i(left_node_data)): 0.9799999999999991 * 0.6655803794523965 = 0.652268771863348
# weighted_prob_node_right * w_i(right_node_data)): 0.02 * 0.0 = 0.0
# column_index: 1, value: 4.1
# weighted_prob_node_left * w_i(left_node_data)): 0.9866666666666657 * 0.6661866024288331 = 0.657304114396448
# weighted_prob_node_right * w_i(right_node_data)): 0.013333333333333334 * 0.0 = 0.0
# column_index: 1, value: 4.2
# weighted_prob_node_left * w_i(left_node_data)): 0.9933333333333323 * 0.6665473782369379 = 0.662103729048691
# weighted_prob_node_right * w_i(right_node_data)): 0.006666666666666667 * 0.0 = 0.0
# column_index: 1, value: 4.4
# weighted_prob_node_left * w_i(left_node_data)): 0.9999999999999989 * 0.6666666666666667 = 0.666666666666666
# weighted_prob_node_right * w_i(right_node_data)): 0.0 * 1.0 = 0.0
# column_index: 2, value: 1.0
# weighted_prob_node_left * w_i(left_node_data)): 0.006666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9933333333333323 * 0.6665473782369379 = 0.662103729048691
# column_index: 2, value: 1.1
# weighted_prob_node_left * w_i(left_node_data)): 0.013333333333333334 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9866666666666657 * 0.6661866024288331 = 0.657304114396448
# column_index: 2, value: 1.2
# weighted_prob_node_left * w_i(left_node_data)): 0.02666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9733333333333323 * 0.66472533691266 = 0.6469993279283217
# column_index: 2, value: 1.3
# weighted_prob_node_left * w_i(left_node_data)): 0.07333333333333333 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9266666666666659 * 0.6516405857183571 = 0.6038536094323438
# column_index: 2, value: 1.4
# weighted_prob_node_left * w_i(left_node_data)): 0.1533333333333333 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.8466666666666658 * 0.6029595105224052 = 0.5105057189089691
# column_index: 2, value: 1.5
# weighted_prob_node_left * w_i(left_node_data)): 0.24666666666666645 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.7533333333333326 * 0.5310914760716342 = 0.40008891197396407
# column_index: 2, value: 1.6
# weighted_prob_node_left * w_i(left_node_data)): 0.29333333333333306 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.7066666666666659 * 0.5070718783456492 = 0.358330794030925
# column_index: 2, value: 1.7
# weighted_prob_node_left * w_i(left_node_data)): 0.3199999999999997 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.6799999999999993 * 0.5007984020457497 = 0.3405429133911094
# column_index: 2, value: 1.9
# weighted_prob_node_left * w_i(left_node_data)): 0.333333333333333 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.666666666666666 * 0.5 = 0.333333333333333
# column_index: 2, value: 3.0
# weighted_prob_node_left * w_i(left_node_data)): 0.33999999999999964 * 0.0007993603837952445 = 0.00027178253049038283
# weighted_prob_node_right * w_i(right_node_data)): 0.6599999999999993 * 0.49979598082432086 = 0.3298653473440514
# column_index: 2, value: 3.3
# weighted_prob_node_left * w_i(left_node_data)): 0.353333333333333 * 0.007148438598327589 = 0.002525781638075746
# weighted_prob_node_right * w_i(right_node_data)): 0.6466666666666661 * 0.4980905925997312 = 0.32209858321449253
# column_index: 2, value: 3.5
# weighted_prob_node_left * w_i(left_node_data)): 0.3666666666666663 * 0.019605920988138736 = 0.007188837695650863
# weighted_prob_node_right * w_i(right_node_data)): 0.6333333333333326 * 0.49449040017093493 = 0.31317725344159175
# column_index: 2, value: 3.6
# weighted_prob_node_left * w_i(left_node_data)): 0.37333333333333296 * 0.02798813800515454 = 0.010448904855257684
# weighted_prob_node_right * w_i(right_node_data)): 0.626666666666666 * 0.49191751071851664 = 0.3082683067169368
# column_index: 2, value: 3.7
# weighted_prob_node_left * w_i(left_node_data)): 0.37999999999999967 * 0.037707384845109715 = 0.014328806241141679
# weighted_prob_node_right * w_i(right_node_data)): 0.6199999999999994 * 0.4887965142490396 = 0.3030538388344043
# column_index: 2, value: 3.8
# weighted_prob_node_left * w_i(left_node_data)): 0.3866666666666663 * 0.04867589399363803 = 0.01882134567754002
# weighted_prob_node_right * w_i(right_node_data)): 0.6133333333333327 * 0.48510325989390646 = 0.2975299994015957
# column_index: 2, value: 3.9
# weighted_prob_node_left * w_i(left_node_data)): 0.4066666666666663 * 0.08806864871104603 = 0.03581458380915868
# weighted_prob_node_right * w_i(right_node_data)): 0.5933333333333328 * 0.4703607478296765 = 0.27908071037894117
# column_index: 2, value: 4.0
# weighted_prob_node_left * w_i(left_node_data)): 0.43999999999999967 * 0.16852003597902798 = 0.07414881583077226
# weighted_prob_node_right * w_i(right_node_data)): 0.5599999999999995 * 0.43242965012999823 = 0.2421606040727988
# column_index: 2, value: 4.1
# weighted_prob_node_left * w_i(left_node_data)): 0.45999999999999963 * 0.22051670301018134 = 0.10143768338468333
# weighted_prob_node_right * w_i(right_node_data)): 0.5399999999999995 * 0.40113466428785327 = 0.21661271871544055
# column_index: 2, value: 4.2
# weighted_prob_node_left * w_i(left_node_data)): 0.48666666666666625 * 0.28828837469771984 = 0.1403003423528902
# weighted_prob_node_right * w_i(right_node_data)): 0.5133333333333329 * 0.3495919652736732 = 0.1794572088404854
# column_index: 2, value: 4.3
# weighted_prob_node_left * w_i(left_node_data)): 0.49999999999999956 * 0.32000000000000006 = 0.1599999999999999
# weighted_prob_node_right * w_i(right_node_data)): 0.49999999999999956 * 0.32000000000000006 = 0.1599999999999999
# column_index: 2, value: 4.4
# weighted_prob_node_left * w_i(left_node_data)): 0.5266666666666662 * 0.3767151176359025 = 0.1984032952882418
# weighted_prob_node_right * w_i(right_node_data)): 0.47333333333333294 * 0.25492859051311867 = 0.12066619950954274
# column_index: 2, value: 4.5
# weighted_prob_node_left * w_i(left_node_data)): 0.5799999999999995 * 0.44998945357593134 = 0.26099388307404
# weighted_prob_node_right * w_i(right_node_data)): 0.41999999999999965 * 0.13955144179423318 = 0.05861160555357789
# column_index: 2, value: 4.6
# weighted_prob_node_left * w_i(left_node_data)): 0.5999999999999995 * 0.47062402435535444 = 0.28237441461321244
# weighted_prob_node_right * w_i(right_node_data)): 0.3999999999999997 * 0.091351853097972 = 0.036540741239188775
# column_index: 2, value: 4.7
# weighted_prob_node_left * w_i(left_node_data)): 0.6333333333333327 * 0.4921464548453345 = 0.3116927547353782
# weighted_prob_node_right * w_i(right_node_data)): 0.3666666666666663 * 0.029108082564498927 = 0.01067296360698293
# column_index: 2, value: 4.8
# weighted_prob_node_left * w_i(left_node_data)): 0.6599999999999994 * 0.49849352227903576 = 0.3290057247041633
# weighted_prob_node_right * w_i(right_node_data)): 0.3399999999999997 * 0.014278601186718864 = 0.0048547244034844094
# column_index: 2, value: 4.9
# weighted_prob_node_left * w_i(left_node_data)): 0.6933333333333327 * 0.506535072740933 = 0.3511976504337132
# weighted_prob_node_right * w_i(right_node_data)): 0.30666666666666637 * 0.004115208842597751 = 0.0012619973783966423
# column_index: 2, value: 5.0
# weighted_prob_node_left * w_i(left_node_data)): 0.7199999999999993 * 0.515664581977254 = 0.3712784990236225
# weighted_prob_node_right * w_i(right_node_data)): 0.27999999999999975 * 0.001188353709487222 = 0.0003327390386564219
# column_index: 2, value: 5.1
# weighted_prob_node_left * w_i(left_node_data)): 0.7733333333333327 * 0.545147793693487 = 0.4215809604562962
# weighted_prob_node_right * w_i(right_node_data)): 0.2266666666666665 * 0.0 = 0.0
# column_index: 2, value: 5.2
# weighted_prob_node_left * w_i(left_node_data)): 0.786666666666666 * 0.5553012286904035 = 0.4368369665697837
# weighted_prob_node_right * w_i(right_node_data)): 0.21333333333333318 * 0.0 = 0.0
# column_index: 2, value: 5.3
# weighted_prob_node_left * w_i(left_node_data)): 0.7999999999999993 * 0.5658436213991769 = 0.4526748971193411
# weighted_prob_node_right * w_i(right_node_data)): 0.19999999999999987 * 0.0 = 0.0
# column_index: 2, value: 5.4
# weighted_prob_node_left * w_i(left_node_data)): 0.8133333333333326 * 0.5765728668399976 = 0.468945931696531
# weighted_prob_node_right * w_i(right_node_data)): 0.18666666666666656 * 0.0 = 0.0
# column_index: 2, value: 5.5
# weighted_prob_node_left * w_i(left_node_data)): 0.8333333333333326 * 0.5925925925925926 = 0.4938271604938267
# weighted_prob_node_right * w_i(right_node_data)): 0.1666666666666666 * 0.0 = 0.0
# column_index: 2, value: 5.6
# weighted_prob_node_left * w_i(left_node_data)): 0.8733333333333325 * 0.6222293591451296 = 0.5434136403200793
# weighted_prob_node_right * w_i(right_node_data)): 0.12666666666666668 * 0.0 = 0.0
# column_index: 2, value: 5.7
# weighted_prob_node_left * w_i(left_node_data)): 0.8933333333333324 * 0.6348898743139706 = 0.5671682877204798
# weighted_prob_node_right * w_i(right_node_data)): 0.10666666666666667 * 0.0 = 0.0
# column_index: 2, value: 5.8
# weighted_prob_node_left * w_i(left_node_data)): 0.9133333333333324 * 0.6456438233740369 = 0.5896880253482865
# weighted_prob_node_right * w_i(right_node_data)): 0.08666666666666667 * 0.0 = 0.0
# column_index: 2, value: 5.9
# weighted_prob_node_left * w_i(left_node_data)): 0.9266666666666658 * 0.6516405857183571 = 0.6038536094323437
# weighted_prob_node_right * w_i(right_node_data)): 0.07333333333333333 * 0.0 = 0.0
# column_index: 2, value: 6.0
# weighted_prob_node_left * w_i(left_node_data)): 0.9399999999999991 * 0.6566483766233984 = 0.6172494740259938
# weighted_prob_node_right * w_i(right_node_data)): 0.060000000000000005 * 0.0 = 0.0
# column_index: 2, value: 6.1
# weighted_prob_node_left * w_i(left_node_data)): 0.9599999999999991 * 0.6622585936471067 = 0.6357682499012218
# weighted_prob_node_right * w_i(right_node_data)): 0.04 * 0.0 = 0.0
# column_index: 2, value: 6.3
# weighted_prob_node_left * w_i(left_node_data)): 0.9666666666666657 * 0.6636187484960929 = 0.6414981235462225
# weighted_prob_node_right * w_i(right_node_data)): 0.03333333333333333 * 0.0 = 0.0
# column_index: 2, value: 6.4
# weighted_prob_node_left * w_i(left_node_data)): 0.9733333333333323 * 0.66472533691266 = 0.6469993279283217
# weighted_prob_node_right * w_i(right_node_data)): 0.02666666666666667 * 0.0 = 0.0
# column_index: 2, value: 6.6
# weighted_prob_node_left * w_i(left_node_data)): 0.979999999999999 * 0.6655803794523965 = 0.6522687718633479
# weighted_prob_node_right * w_i(right_node_data)): 0.02 * 0.0 = 0.0
# column_index: 2, value: 6.7
# weighted_prob_node_left * w_i(left_node_data)): 0.9933333333333323 * 0.6665473782369378 = 0.6621037290486909
# weighted_prob_node_right * w_i(right_node_data)): 0.006666666666666667 * 0.0 = 0.0
# column_index: 2, value: 6.9
# weighted_prob_node_left * w_i(left_node_data)): 0.9999999999999989 * 0.6666666666666667 = 0.666666666666666
# weighted_prob_node_right * w_i(right_node_data)): 0.0 * 1.0 = 0.0
# column_index: 3, value: 0.1
# weighted_prob_node_left * w_i(left_node_data)): 0.04 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9599999999999991 * 0.6622585936471067 = 0.6357682499012218
# column_index: 3, value: 0.2
# weighted_prob_node_left * w_i(left_node_data)): 0.2266666666666665 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.7733333333333327 * 0.5451477936934871 = 0.42158096045629634
# column_index: 3, value: 0.3
# weighted_prob_node_left * w_i(left_node_data)): 0.2733333333333331 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.7266666666666659 * 0.5155605349604853 = 0.3746406554046189
# column_index: 3, value: 0.4
# weighted_prob_node_left * w_i(left_node_data)): 0.3199999999999997 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.6799999999999993 * 0.5007984020457497 = 0.3405429133911094
# column_index: 3, value: 0.5
# weighted_prob_node_left * w_i(left_node_data)): 0.3266666666666663 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.6733333333333327 * 0.5001999000319912 = 0.3368012660215404
# column_index: 3, value: 0.6
# weighted_prob_node_left * w_i(left_node_data)): 0.333333333333333 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.666666666666666 * 0.5 = 0.333333333333333
# column_index: 3, value: 1.0
# weighted_prob_node_left * w_i(left_node_data)): 0.37999999999999967 * 0.037707384845109715 = 0.014328806241141679
# weighted_prob_node_right * w_i(right_node_data)): 0.6199999999999994 * 0.4887965142490396 = 0.3030538388344043
# column_index: 3, value: 1.1
# weighted_prob_node_left * w_i(left_node_data)): 0.39999999999999963 * 0.07396449704142039 = 0.029585798816568126
# weighted_prob_node_right * w_i(right_node_data)): 0.5999999999999994 * 0.47590719809637116 = 0.28554431885782244
# column_index: 3, value: 1.2
# weighted_prob_node_left * w_i(left_node_data)): 0.433333333333333 * 0.15150239878798089 = 0.06565103947479167
# weighted_prob_node_right * w_i(right_node_data)): 0.5666666666666661 * 0.4414215575874961 = 0.25013888263291423
# column_index: 3, value: 1.3
# weighted_prob_node_left * w_i(left_node_data)): 0.5199999999999996 * 0.36347937291648436 = 0.1890092739165717
# weighted_prob_node_right * w_i(right_node_data)): 0.47999999999999965 * 0.2717801464827607 = 0.13045447031172505
# column_index: 3, value: 1.4
# weighted_prob_node_left * w_i(left_node_data)): 0.5733333333333328 * 0.4417212727208294 = 0.2532535296932753
# weighted_prob_node_right * w_i(right_node_data)): 0.4266666666666663 * 0.15668060156534158 = 0.06685039000121235
# column_index: 3, value: 1.5
# weighted_prob_node_left * w_i(left_node_data)): 0.6533333333333327 * 0.49649134345237234 = 0.3243743443888829
# weighted_prob_node_right * w_i(right_node_data)): 0.34666666666666635 * 0.02213091563682923 = 0.007672050754100792
# column_index: 3, value: 1.6
# weighted_prob_node_left * w_i(left_node_data)): 0.6799999999999993 * 0.5024761970351752 = 0.3416838139839188
# weighted_prob_node_right * w_i(right_node_data)): 0.3199999999999997 * 0.0037664649341402345 = 0.0012052687789248738
# column_index: 3, value: 1.7
# weighted_prob_node_left * w_i(left_node_data)): 0.6933333333333326 * 0.5048345229246687 = 0.35001860256110323
# weighted_prob_node_right * w_i(right_node_data)): 0.30666666666666637 * 0.0009866795820179242 = 0.00030258173848549645
# column_index: 3, value: 1.8
# weighted_prob_node_left * w_i(left_node_data)): 0.7733333333333327 * 0.545147793693487 = 0.4215809604562962
# weighted_prob_node_right * w_i(right_node_data)): 0.2266666666666665 * 0.0 = 0.0
# column_index: 3, value: 1.9
# weighted_prob_node_left * w_i(left_node_data)): 0.806666666666666 * 0.5711973130013662 = 0.46076583248776837
# weighted_prob_node_right * w_i(right_node_data)): 0.19333333333333322 * 0.0 = 0.0
# column_index: 3, value: 2.0
# weighted_prob_node_left * w_i(left_node_data)): 0.8466666666666659 * 0.6029595105224052 = 0.5105057189089692
# weighted_prob_node_right * w_i(right_node_data)): 0.1533333333333333 * 0.0 = 0.0
# column_index: 3, value: 2.1
# weighted_prob_node_left * w_i(left_node_data)): 0.8866666666666658 * 0.6308676728489091 = 0.5593693365926988
# weighted_prob_node_right * w_i(right_node_data)): 0.11333333333333334 * 0.0 = 0.0
# column_index: 3, value: 2.2
# weighted_prob_node_left * w_i(left_node_data)): 0.9066666666666657 * 0.6422867466728235 = 0.582339983650026
# weighted_prob_node_right * w_i(right_node_data)): 0.09333333333333334 * 0.0 = 0.0
# column_index: 3, value: 2.3
# weighted_prob_node_left * w_i(left_node_data)): 0.9599999999999991 * 0.6622585936471067 = 0.6357682499012218
# weighted_prob_node_right * w_i(right_node_data)): 0.04 * 0.0 = 0.0
# column_index: 3, value: 2.4
# weighted_prob_node_left * w_i(left_node_data)): 0.979999999999999 * 0.6655803794523965 = 0.6522687718633479
# weighted_prob_node_right * w_i(right_node_data)): 0.02 * 0.0 = 0.0
# column_index: 3, value: 2.5
# weighted_prob_node_left * w_i(left_node_data)): 0.9999999999999989 * 0.6666666666666667 = 0.666666666666666
# weighted_prob_node_right * w_i(right_node_data)): 0.0 * 1.0 = 0.0
# split_column_index: 2, split_value: 3.9
# Change in overall_metric: 0.31489529418809986
# Left leaf: Iris-setosa, Right leaf: Iris-virginica
# Boost Called
# Learner error: 0.3333333333333333
# Learner weight: 1.3862943611198908
# 0: Sample weight(sum) 2.0
# Total stumps: 1
# New Stump Created!
# column_index: 0, value: 4.3
# weighted_prob_node_left * w_i(left_node_data)): 0.0033333333333333335 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9966666666666666 * 0.4955192695385272 = 0.4938675386400654
# column_index: 0, value: 4.4
# weighted_prob_node_left * w_i(left_node_data)): 0.013333333333333334 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9866666666666667 * 0.48167965825516323 = 0.47525726281176106
# column_index: 0, value: 4.5
# weighted_prob_node_left * w_i(left_node_data)): 0.016666666666666666 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9833333333333334 * 0.4769508325902574 = 0.46900165204708644
# column_index: 0, value: 4.6
# weighted_prob_node_left * w_i(left_node_data)): 0.030000000000000002 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.97 * 0.45760642347842706 = 0.44387823077407423
# column_index: 0, value: 4.7
# weighted_prob_node_left * w_i(left_node_data)): 0.03666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9633333333333334 * 0.4477628468501864 = 0.43134487579901293
# column_index: 0, value: 4.8
# weighted_prob_node_left * w_i(left_node_data)): 0.05333333333333334 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9466666666666668 * 0.42308729793479327 = 0.40052264204493765
# column_index: 0, value: 4.9
# weighted_prob_node_left * w_i(left_node_data)): 0.08333333333333333 * 0.024435299497028162 = 0.00203627495808568
# weighted_prob_node_right * w_i(right_node_data)): 0.9166666666666667 * 0.4066759007385804 = 0.3727862423436987
# column_index: 0, value: 5.0
# weighted_prob_node_left * w_i(left_node_data)): 0.13666666666666663 * 0.08617873393458286 = 0.011777760304392988
# weighted_prob_node_right * w_i(right_node_data)): 0.8633333333333335 * 0.38802717747828075 = 0.3349967965562491
# column_index: 0, value: 5.1
# weighted_prob_node_left * w_i(left_node_data)): 0.17666666666666658 * 0.09102525966071773 = 0.01608112920672679
# weighted_prob_node_right * w_i(right_node_data)): 0.8233333333333335 * 0.3670190312581505 = 0.302179002402544
# column_index: 0, value: 5.2
# weighted_prob_node_left * w_i(left_node_data)): 0.19999999999999993 * 0.11685882007720594 = 0.02337176401544118
# weighted_prob_node_right * w_i(right_node_data)): 0.8000000000000003 * 0.3672656775667045 = 0.29381254205336366
# column_index: 0, value: 5.3
# weighted_prob_node_left * w_i(left_node_data)): 0.20333333333333323 * 0.1117715795356401 = 0.022726887838913475
# weighted_prob_node_right * w_i(right_node_data)): 0.7966666666666669 * 0.364797667538719 = 0.2906221418058462
# column_index: 0, value: 5.4
# weighted_prob_node_left * w_i(left_node_data)): 0.2333333333333332 * 0.12477181507358415 = 0.02911342351716962
# weighted_prob_node_right * w_i(right_node_data)): 0.766666666666667 * 0.36444299417280834 = 0.2794062955324865
# column_index: 0, value: 5.5
# weighted_prob_node_left * w_i(left_node_data)): 0.3066666666666666 * 0.29537138539326047 = 0.09058055818726651
# weighted_prob_node_right * w_i(right_node_data)): 0.6933333333333338 * 0.40705332574818764 = 0.28222363918541027
# column_index: 0, value: 5.6
# weighted_prob_node_left * w_i(left_node_data)): 0.37666666666666654 * 0.4342262469712028 = 0.16355855302581968
# weighted_prob_node_right * w_i(right_node_data)): 0.6233333333333337 * 0.4453703047770131 = 0.27761415664433836
# column_index: 0, value: 5.7
# weighted_prob_node_left * w_i(left_node_data)): 0.4533333333333333 * 0.4905041109439433 = 0.22236186362792096
# weighted_prob_node_right * w_i(right_node_data)): 0.5466666666666669 * 0.4787109380280503 = 0.2616953127886676
# column_index: 0, value: 5.8
# weighted_prob_node_left * w_i(left_node_data)): 0.5066666666666667 * 0.506535072740933 = 0.25664443685540606
# weighted_prob_node_right * w_i(right_node_data)): 0.4933333333333335 * 0.48630202140309153 = 0.23990899722552525
# column_index: 0, value: 5.9
# weighted_prob_node_left * w_i(left_node_data)): 0.5366666666666667 * 0.5084434088573356 = 0.2728646294201035
# weighted_prob_node_right * w_i(right_node_data)): 0.46333333333333343 * 0.4939983739006826 = 0.22888591324064964
# column_index: 0, value: 6.0
# weighted_prob_node_left * w_i(left_node_data)): 0.5966666666666669 * 0.4970113541608071 = 0.296550107982615
# weighted_prob_node_right * w_i(right_node_data)): 0.4033333333333333 * 0.4996952613205009 = 0.2015437553992687
# column_index: 0, value: 6.1
# weighted_prob_node_left * w_i(left_node_data)): 0.656666666666667 * 0.4733091287344592 = 0.3108063278689617
# weighted_prob_node_right * w_i(right_node_data)): 0.34333333333333327 * 0.480931909325655 = 0.16511995553514153
# column_index: 0, value: 6.2
# weighted_prob_node_left * w_i(left_node_data)): 0.6900000000000004 * 0.46241888772150275 = 0.3190690325278371
# weighted_prob_node_right * w_i(right_node_data)): 0.30999999999999994 * 0.46308578164300085 = 0.14355659230933024
# column_index: 0, value: 6.3
# weighted_prob_node_left * w_i(left_node_data)): 0.7500000000000004 * 0.45764608949605357 = 0.34323456712204037
# weighted_prob_node_right * w_i(right_node_data)): 0.25 * 0.4455157385567703 = 0.11137893463919257
# column_index: 0, value: 6.4
# weighted_prob_node_left * w_i(left_node_data)): 0.7933333333333337 * 0.4607043731778421 = 0.36549213605442155
# weighted_prob_node_right * w_i(right_node_data)): 0.20666666666666667 * 0.4380480000000001 = 0.09052992000000003
# column_index: 0, value: 6.5
# weighted_prob_node_left * w_i(left_node_data)): 0.8200000000000003 * 0.47012604334634 = 0.38550335554399895
# weighted_prob_node_right * w_i(right_node_data)): 0.18000000000000002 * 0.45253469685902126 = 0.08145624543462383
# column_index: 0, value: 6.6
# weighted_prob_node_left * w_i(left_node_data)): 0.8466666666666669 * 0.4504525625344602 = 0.38138316961250973
# weighted_prob_node_right * w_i(right_node_data)): 0.15333333333333335 * 0.3534423303176599 = 0.05419449064870786
# column_index: 0, value: 6.7
# weighted_prob_node_left * w_i(left_node_data)): 0.9033333333333334 * 0.4461039589650576 = 0.4029805762651021
# weighted_prob_node_right * w_i(right_node_data)): 0.09666666666666668 * 0.1969988165680474 = 0.019043218934911253
# column_index: 0, value: 6.8
# weighted_prob_node_left * w_i(left_node_data)): 0.9233333333333335 * 0.4465541993290105 = 0.4123183773804531
# weighted_prob_node_right * w_i(right_node_data)): 0.07666666666666667 * 0.1239648077684612 = 0.009503968595582026
# column_index: 0, value: 6.9
# weighted_prob_node_left * w_i(left_node_data)): 0.9466666666666668 * 0.4520682032561847 = 0.4279578990825216
# weighted_prob_node_right * w_i(right_node_data)): 0.05333333333333334 * 0.05259313367421492 = 0.0028049671292914627
# column_index: 0, value: 7.0
# weighted_prob_node_left * w_i(left_node_data)): 0.9600000000000001 * 0.44282119873642556 = 0.42510835078696857
# weighted_prob_node_right * w_i(right_node_data)): 0.04 * 0.0 = 0.0
# column_index: 0, value: 7.1
# weighted_prob_node_left * w_i(left_node_data)): 0.9633333333333334 * 0.4477628468501864 = 0.43134487579901293
# weighted_prob_node_right * w_i(right_node_data)): 0.03666666666666667 * 0.0 = 0.0
# column_index: 0, value: 7.2
# weighted_prob_node_left * w_i(left_node_data)): 0.9733333333333334 * 0.4624949159963747 = 0.4501617182364714
# weighted_prob_node_right * w_i(right_node_data)): 0.02666666666666667 * 0.0 = 0.0
# column_index: 0, value: 7.3
# weighted_prob_node_left * w_i(left_node_data)): 0.9766666666666667 * 0.4673525843548827 = 0.45644769071993546
# weighted_prob_node_right * w_i(right_node_data)): 0.023333333333333334 * 0.0 = 0.0
# column_index: 0, value: 7.4
# weighted_prob_node_left * w_i(left_node_data)): 0.98 * 0.4721732198551368 = 0.4627297554580341
# weighted_prob_node_right * w_i(right_node_data)): 0.02 * 0.0 = 0.0
# column_index: 0, value: 7.6
# weighted_prob_node_left * w_i(left_node_data)): 0.9833333333333334 * 0.4769508325902573 = 0.4690016520470863
# weighted_prob_node_right * w_i(right_node_data)): 0.016666666666666666 * 0.0 = 0.0
# column_index: 0, value: 7.7
# weighted_prob_node_left * w_i(left_node_data)): 0.9966666666666666 * 0.4955192695385271 = 0.4938675386400653
# weighted_prob_node_right * w_i(right_node_data)): 0.0033333333333333335 * 0.0 = 0.0
# column_index: 0, value: 7.9
# weighted_prob_node_left * w_i(left_node_data)): 1.0 * 0.49999999999999967 = 0.49999999999999967
# weighted_prob_node_right * w_i(right_node_data)): 0.0 * 1.0 = 0.0
# column_index: 1, value: 2.0
# weighted_prob_node_left * w_i(left_node_data)): 0.013333333333333338 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9866666666666667 * 0.5089160745910609 = 0.5021305269298468
# column_index: 1, value: 2.2
# weighted_prob_node_left * w_i(left_node_data)): 0.04333333333333335 * 0.0525931336742147 = 0.0022790357925493044
# weighted_prob_node_right * w_i(right_node_data)): 0.9566666666666668 * 0.5225901999536638 = 0.49994462462233846
# column_index: 1, value: 2.3
# weighted_prob_node_left * w_i(left_node_data)): 0.08666666666666668 * 0.027115781572527697 = 0.002350034402952401
# weighted_prob_node_right * w_i(right_node_data)): 0.9133333333333333 * 0.5457549122147756 = 0.4984561531561617
# column_index: 1, value: 2.4
# weighted_prob_node_left * w_i(left_node_data)): 0.1266666666666667 * 0.012213481877376364 = 0.0015470410378010066
# weighted_prob_node_right * w_i(right_node_data)): 0.8733333333333335 * 0.5728841287059567 = 0.5003188057365356
# column_index: 1, value: 2.5
# weighted_prob_node_left * w_i(left_node_data)): 0.19333333333333338 * 0.0714320500645289 = 0.013810196345808925
# weighted_prob_node_right * w_i(right_node_data)): 0.8066666666666671 * 0.5935526470866723 = 0.4787991353165826
# column_index: 1, value: 2.6
# weighted_prob_node_left * w_i(left_node_data)): 0.24000000000000007 * 0.08886010632210806 = 0.02132642551730594
# weighted_prob_node_right * w_i(right_node_data)): 0.7600000000000002 * 0.6118628266240473 = 0.4650157482342761
# column_index: 1, value: 2.7
# weighted_prob_node_left * w_i(left_node_data)): 0.3200000000000002 * 0.12107351259321053 = 0.03874352402982739
# weighted_prob_node_right * w_i(right_node_data)): 0.6800000000000002 * 0.634652968187573 = 0.43156401836754976
# column_index: 1, value: 2.8
# weighted_prob_node_left * w_i(left_node_data)): 0.426666666666667 * 0.19654259487231784 = 0.08385817381218902
# weighted_prob_node_right * w_i(right_node_data)): 0.5733333333333333 * 0.6279126263092798 = 0.360003239083987
# column_index: 1, value: 2.9
# weighted_prob_node_left * w_i(left_node_data)): 0.5300000000000005 * 0.16030069320356777 = 0.08495936739789099
# weighted_prob_node_right * w_i(right_node_data)): 0.46999999999999986 * 0.5935532230518912 = 0.27897001483438877
# column_index: 1, value: 3.0
# weighted_prob_node_left * w_i(left_node_data)): 0.696666666666667 * 0.24352415391768678 = 0.1696551605626552
# weighted_prob_node_right * w_i(right_node_data)): 0.30333333333333323 * 0.388396394922912 = 0.1178135731266166
# column_index: 1, value: 3.1
# weighted_prob_node_left * w_i(left_node_data)): 0.7666666666666669 * 0.2732052618549531 = 0.20945736742213078
# weighted_prob_node_right * w_i(right_node_data)): 0.23333333333333325 * 0.287107479415172 = 0.06699174519687344
# column_index: 1, value: 3.2
# weighted_prob_node_left * w_i(left_node_data)): 0.8400000000000003 * 0.3101342853665461 = 0.2605127997078988
# weighted_prob_node_right * w_i(right_node_data)): 0.15999999999999995 * 0.13610586011342152 = 0.021776937618147436
# column_index: 1, value: 3.3
# weighted_prob_node_left * w_i(left_node_data)): 0.8700000000000001 * 0.33310609731970564 = 0.28980230466814394
# weighted_prob_node_right * w_i(right_node_data)): 0.12999999999999995 * 0.060715539586184364 = 0.007893020146203964
# column_index: 1, value: 3.4
# weighted_prob_node_left * w_i(left_node_data)): 0.92 * 0.3800034526797902 = 0.349603176465407
# weighted_prob_node_right * w_i(right_node_data)): 0.07999999999999999 * 0.039200000000000124 = 0.0031360000000000094
# column_index: 1, value: 3.5
# weighted_prob_node_left * w_i(left_node_data)): 0.9400000000000001 * 0.4105451474241292 = 0.38591243857868146
# weighted_prob_node_right * w_i(right_node_data)): 0.060000000000000005 * 0.07396449704142039 = 0.004437869822485224
# column_index: 1, value: 3.6
# weighted_prob_node_left * w_i(left_node_data)): 0.95 * 0.42668069330642333 = 0.40534665864110214
# weighted_prob_node_right * w_i(right_node_data)): 0.05 * 0.045173577466671055 = 0.0022586788733335527
# column_index: 1, value: 3.7
# weighted_prob_node_left * w_i(left_node_data)): 0.96 * 0.4420249456738361 = 0.4243439478468826
# weighted_prob_node_right * w_i(right_node_data)): 0.04 * 0.07396449704142016 = 0.0029585798816568064
# column_index: 1, value: 3.8
# weighted_prob_node_left * w_i(left_node_data)): 0.98 * 0.47217321985513705 = 0.4627297554580343
# weighted_prob_node_right * w_i(right_node_data)): 0.02 * 0.0 = 0.0
# column_index: 1, value: 3.9
# weighted_prob_node_left * w_i(left_node_data)): 0.9866666666666667 * 0.48167965825516323 = 0.47525726281176106
# weighted_prob_node_right * w_i(right_node_data)): 0.013333333333333334 * 0.0 = 0.0
# column_index: 1, value: 4.0
# weighted_prob_node_left * w_i(left_node_data)): 0.99 * 0.48635416397577236 = 0.48149062233601464
# weighted_prob_node_right * w_i(right_node_data)): 0.01 * 0.0 = 0.0
# column_index: 1, value: 4.1
# weighted_prob_node_left * w_i(left_node_data)): 0.9933333333333333 * 0.4909690531802343 = 0.48769592615903273
# weighted_prob_node_right * w_i(right_node_data)): 0.006666666666666667 * 0.0 = 0.0
# column_index: 1, value: 4.2
# weighted_prob_node_left * w_i(left_node_data)): 0.9966666666666666 * 0.4955192695385272 = 0.4938675386400654
# weighted_prob_node_right * w_i(right_node_data)): 0.0033333333333333335 * 0.0 = 0.0
# column_index: 1, value: 4.4
# weighted_prob_node_left * w_i(left_node_data)): 1.0 * 0.49999999999999967 = 0.49999999999999967
# weighted_prob_node_right * w_i(right_node_data)): 0.0 * 1.0 = 0.0
# column_index: 2, value: 1.0
# weighted_prob_node_left * w_i(left_node_data)): 0.0033333333333333335 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9966666666666666 * 0.4955192695385272 = 0.4938675386400654
# column_index: 2, value: 1.1
# weighted_prob_node_left * w_i(left_node_data)): 0.006666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9933333333333333 * 0.4909690531802343 = 0.48769592615903273
# column_index: 2, value: 1.2
# weighted_prob_node_left * w_i(left_node_data)): 0.013333333333333334 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9866666666666667 * 0.48167965825516323 = 0.47525726281176106
# column_index: 2, value: 1.3
# weighted_prob_node_left * w_i(left_node_data)): 0.03666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9633333333333334 * 0.4477628468501864 = 0.43134487579901293
# column_index: 2, value: 1.4
# weighted_prob_node_left * w_i(left_node_data)): 0.07666666666666665 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9233333333333335 * 0.3898427944146352 = 0.35995484684284657
# column_index: 2, value: 1.5
# weighted_prob_node_left * w_i(left_node_data)): 0.12333333333333323 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.8766666666666668 * 0.3378429715961252 = 0.29617567176593645
# column_index: 2, value: 1.6
# weighted_prob_node_left * w_i(left_node_data)): 0.14666666666666653 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.8533333333333335 * 0.3238916973360497 = 0.2763875817267625
# column_index: 2, value: 1.7
# weighted_prob_node_left * w_i(left_node_data)): 0.15999999999999984 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.8400000000000002 * 0.3204348888585976 = 0.26916530664122207
# column_index: 2, value: 1.9
# weighted_prob_node_left * w_i(left_node_data)): 0.1666666666666665 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.8333333333333335 * 0.3199999999999996 = 0.2666666666666664
# column_index: 2, value: 3.0
# weighted_prob_node_left * w_i(left_node_data)): 0.17999999999999983 * 0.0031897845236759093 = 0.0005741612142616631
# weighted_prob_node_right * w_i(right_node_data)): 0.8200000000000002 * 0.3277663204420467 = 0.26876838276247833
# column_index: 2, value: 3.3
# weighted_prob_node_left * w_i(left_node_data)): 0.2066666666666665 * 0.02798813800515454 = 0.005784215187731933
# weighted_prob_node_right * w_i(right_node_data)): 0.7933333333333336 * 0.34380013038569346 = 0.2727481034393169
# column_index: 2, value: 3.5
# weighted_prob_node_left * w_i(left_node_data)): 0.23333333333333317 * 0.07396449704142039 = 0.017258382642998078
# weighted_prob_node_right * w_i(right_node_data)): 0.7666666666666669 * 0.3604485582057668 = 0.2763438946244213
# column_index: 2, value: 3.6
# weighted_prob_node_left * w_i(left_node_data)): 0.24666666666666653 * 0.10299344732800675 = 0.025405050340908317
# weighted_prob_node_right * w_i(right_node_data)): 0.7533333333333336 * 0.3689743777788378 = 0.27796069792672456
# column_index: 2, value: 3.7
# weighted_prob_node_left * w_i(left_node_data)): 0.25999999999999984 * 0.1348299271808331 = 0.03505578106701658
# weighted_prob_node_right * w_i(right_node_data)): 0.7400000000000003 * 0.37761351850677904 = 0.27943400369501664
# column_index: 2, value: 3.8
# weighted_prob_node_left * w_i(left_node_data)): 0.2733333333333332 * 0.16852003597902798 = 0.04606214316760096
# weighted_prob_node_right * w_i(right_node_data)): 0.726666666666667 * 0.3863458880269741 = 0.2807446786329347
# column_index: 2, value: 3.9
# weighted_prob_node_left * w_i(left_node_data)): 0.31333333333333324 * 0.2717801464827607 = 0.085157779231265
# weighted_prob_node_right * w_i(right_node_data)): 0.6866666666666671 * 0.41283812012031285 = 0.2834821758159483
# column_index: 2, value: 4.0
# weighted_prob_node_left * w_i(left_node_data)): 0.3799999999999999 * 0.4122855953854936 = 0.15666852624648753
# weighted_prob_node_right * w_i(right_node_data)): 0.6200000000000003 * 0.45555415088647033 = 0.28244357354961175
# column_index: 2, value: 4.1
# weighted_prob_node_left * w_i(left_node_data)): 0.41999999999999993 * 0.4641553760764292 = 0.19494525795210024
# weighted_prob_node_right * w_i(right_node_data)): 0.5800000000000003 * 0.47755900065039447 = 0.2769842203772289
# column_index: 2, value: 4.2
# weighted_prob_node_left * w_i(left_node_data)): 0.4733333333333334 * 0.49653980278077325 = 0.23502883998289936
# weighted_prob_node_right * w_i(right_node_data)): 0.5266666666666668 * 0.497050153928728 = 0.2617797477357968
# column_index: 2, value: 4.3
# weighted_prob_node_left * w_i(left_node_data)): 0.5000000000000001 * 0.5 = 0.25000000000000006
# weighted_prob_node_right * w_i(right_node_data)): 0.5000000000000001 * 0.5 = 0.25000000000000006
# column_index: 2, value: 4.4
# weighted_prob_node_left * w_i(left_node_data)): 0.5533333333333336 * 0.4891455064220557 = 0.2706605135535376
# weighted_prob_node_right * w_i(right_node_data)): 0.44666666666666666 * 0.48510325989390657 = 0.21667945608594494
# column_index: 2, value: 4.5
# weighted_prob_node_left * w_i(left_node_data)): 0.6500000000000004 * 0.43914169208959286 = 0.28544209985823554
# weighted_prob_node_right * w_i(right_node_data)): 0.34999999999999987 * 0.37112426035503 = 0.12989349112426044
# column_index: 2, value: 4.6
# ...
# weighted_prob_node_left * w_i(left_node_data)): 0.9987654320987644 * 0.4818624265292709 = 0.48126753464466643
# weighted_prob_node_right * w_i(right_node_data)): 0.0012345679012345674 * 0.0 = 0.0
# column_index: 1, value: 4.2
# weighted_prob_node_left * w_i(left_node_data)): 0.9993827160493818 * 0.4830344411010804 = 0.4827362716929929
# weighted_prob_node_right * w_i(right_node_data)): 0.0006172839506172837 * 0.0 = 0.0
# column_index: 1, value: 4.4
# weighted_prob_node_left * w_i(left_node_data)): 0.999999999999999 * 0.484223410443281 = 0.4842234104432805
# weighted_prob_node_right * w_i(right_node_data)): 0.0 * 1.0 = 0.0
# column_index: 2, value: 1.0
# weighted_prob_node_left * w_i(left_node_data)): 0.0006172839506172837 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9993827160493818 * 0.4830344411010804 = 0.4827362716929929
# column_index: 2, value: 1.1
# weighted_prob_node_left * w_i(left_node_data)): 0.0012345679012345674 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9987654320987644 * 0.4818624265292709 = 0.48126753464466643
# column_index: 2, value: 1.2
# weighted_prob_node_left * w_i(left_node_data)): 0.002469135802469135 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9975308641975299 * 0.47957083105935716 = 0.47838670555056817
# column_index: 2, value: 1.3
# weighted_prob_node_left * w_i(left_node_data)): 0.00679012345679012 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9932098765432089 * 0.4721406554846733 = 0.4689347621449621
# column_index: 2, value: 1.4
# weighted_prob_node_left * w_i(left_node_data)): 0.01419753086419753 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9858024691358015 * 0.4618184684936746 = 0.45526178653357874
# column_index: 2, value: 1.5
# weighted_prob_node_left * w_i(left_node_data)): 0.022839506172839488 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9771604938271595 * 0.4542104357535418 = 0.4438364937023802
# column_index: 2, value: 1.6
# weighted_prob_node_left * w_i(left_node_data)): 0.027160493827160466 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9728395061728385 * 0.45236471163998726 = 0.44007826268186373
# column_index: 2, value: 1.7
# weighted_prob_node_left * w_i(left_node_data)): 0.029629629629629596 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9703703703703694 * 0.45191837136605206 = 0.4385281973996501
# column_index: 2, value: 1.9
# weighted_prob_node_left * w_i(left_node_data)): 0.03086419753086416 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9691358024691349 * 0.4518625170868379 = 0.4379161431026758
# column_index: 2, value: 3.0
# weighted_prob_node_left * w_i(left_node_data)): 0.043562610229276856 * 0.016189611912388324 = 0.0007052617535026301
# weighted_prob_node_right * w_i(right_node_data)): 0.9564373897707222 * 0.45739377204157483 = 0.4374685054288286
# column_index: 2, value: 3.3
# weighted_prob_node_left * w_i(left_node_data)): 0.06895943562610224 * 0.12839324436866573 = 0.008853925669867419
# weighted_prob_node_right * w_i(right_node_data)): 0.9310405643738969 * 0.4679086089850071 = 0.4356418953848061
# column_index: 2, value: 3.5
# weighted_prob_node_left * w_i(left_node_data)): 0.09435626102292763 * 0.2830125109498891 = 0.026704002355941902
# weighted_prob_node_right * w_i(right_node_data)): 0.9056437389770716 * 0.47748091321069674 = 0.432427599530322
# column_index: 2, value: 3.6
# weighted_prob_node_left * w_i(left_node_data)): 0.10705467372134031 * 0.3526092979216172 = 0.03774847334010961
# weighted_prob_node_right * w_i(right_node_data)): 0.892945326278659 * 0.48182398622384115 = 0.4302424765875319
# column_index: 2, value: 3.7
# weighted_prob_node_left * w_i(left_node_data)): 0.11975308641975302 * 0.4095541840185457 = 0.049045377592344334
# weighted_prob_node_right * w_i(right_node_data)): 0.8802469135802463 * 0.4858182481121146 = 0.4276400134616512
# column_index: 2, value: 3.8
# weighted_prob_node_left * w_i(left_node_data)): 0.1324514991181657 * 0.451926325876407 = 0.05985831935329479
# weighted_prob_node_right * w_i(right_node_data)): 0.8675485008818337 * 0.4894199849067905 = 0.4245955742074958
# column_index: 2, value: 3.9
# weighted_prob_node_left * w_i(left_node_data)): 0.17054673721340377 * 0.4999976321770272 = 0.08527296478221957
# weighted_prob_node_right * w_i(right_node_data)): 0.8294532627865956 * 0.4973885287651614 = 0.4125605380568876
# column_index: 2, value: 4.0
# weighted_prob_node_left * w_i(left_node_data)): 0.23403880070546718 * 0.4365637729777212 = 0.1021728618591597
# weighted_prob_node_right * w_i(right_node_data)): 0.7659611992945321 * 0.4979060226130335 = 0.38137669421664955
# column_index: 2, value: 4.1
# weighted_prob_node_left * w_i(left_node_data)): 0.2721340388007052 * 0.3768496490131763 = 0.10255361700658386
# weighted_prob_node_right * w_i(right_node_data)): 0.7278659611992939 * 0.48784812543192757 = 0.3550880447367837
# column_index: 2, value: 4.2
# weighted_prob_node_left * w_i(left_node_data)): 0.322927689594356 * 0.3038292157553574 = 0.09811486667514267
# weighted_prob_node_right * w_i(right_node_data)): 0.6770723104056431 * 0.4588063498293703 = 0.3106450753077515
# column_index: 2, value: 4.3
# weighted_prob_node_left * w_i(left_node_data)): 0.34832451499118144 * 0.2725797728501891 = 0.09494621717444852
# weighted_prob_node_right * w_i(right_node_data)): 0.6516754850088178 * 0.4366345473804809 = 0.2845440304357805
# column_index: 2, value: 4.4
# weighted_prob_node_left * w_i(left_node_data)): 0.3991181657848323 * 0.2206353035636328 = 0.0880595576656968
# weighted_prob_node_right * w_i(right_node_data)): 0.6008818342151669 * 0.37599798425321307 = 0.2259303584392761
# column_index: 2, value: 4.5
# weighted_prob_node_left * w_i(left_node_data)): 0.5197530864197529 * 0.1597277514485248 = 0.08301899180225793
# weighted_prob_node_right * w_i(right_node_data)): 0.4802469135802465 * 0.24622078365227973 = 0.11824677140831695
# column_index: 2, value: 4.6
# weighted_prob_node_left * w_i(left_node_data)): 0.5578483245149911 * 0.1396466686846013 = 0.07790166014980492
# weighted_prob_node_right * w_i(right_node_data)): 0.44215167548500844 * 0.17021911382856847 = 0.07526266637887492
# column_index: 2, value: 4.7
# weighted_prob_node_left * w_i(left_node_data)): 0.6213403880070544 * 0.11330715123551727 = 0.07040230931265029
# weighted_prob_node_right * w_i(right_node_data)): 0.378659611992945 * 0.058052195381258054 = 0.02198202177840581
# column_index: 2, value: 4.8
# weighted_prob_node_left * w_i(left_node_data)): 0.6590828924162253 * 0.11100187969631237 = 0.07315943993388342
# weighted_prob_node_right * w_i(right_node_data)): 0.340917107583774 * 0.02893157905060173 = 0.009863270247762453
# column_index: 2, value: 4.9
# weighted_prob_node_left * w_i(left_node_data)): 0.7029982363315692 * 0.11671541387917372 = 0.08205073010976828
# weighted_prob_node_right * w_i(right_node_data)): 0.2970017636684302 * 0.008428788375768548 = 0.0025033650131912216
# column_index: 2, value: 5.0
# weighted_prob_node_left * w_i(left_node_data)): 0.7342151675485004 * 0.13124936464502246 = 0.09636527425347939
# weighted_prob_node_right * w_i(right_node_data)): 0.2657848324514991 * 0.0024415433437936507 = 0.0006489251885532682
# column_index: 2, value: 5.1
# weighted_prob_node_left * w_i(left_node_data)): 0.7901234567901229 * 0.1851494509988375 = 0.14629092424599496
# weighted_prob_node_right * w_i(right_node_data)): 0.2098765432098765 * 0.0 = 0.0
# column_index: 2, value: 5.2
# weighted_prob_node_left * w_i(left_node_data)): 0.8024691358024685 * 0.20483524223671123 = 0.16437395981958294
# weighted_prob_node_right * w_i(right_node_data)): 0.19753086419753083 * 0.0 = 0.0
# column_index: 2, value: 5.3
# weighted_prob_node_left * w_i(left_node_data)): 0.8148148148148142 * 0.2253326270518914 = 0.18360436278302247
# weighted_prob_node_right * w_i(right_node_data)): 0.18518518518518515 * 0.0 = 0.0
# column_index: 2, value: 5.4
# weighted_prob_node_left * w_i(left_node_data)): 0.82716049382716 * 0.24636407303543428 = 0.20378262831326033
# weighted_prob_node_right * w_i(right_node_data)): 0.17283950617283947 * 0.0 = 0.0
# column_index: 2, value: 5.5
# weighted_prob_node_left * w_i(left_node_data)): 0.8456790123456784 * 0.2783311026361259 = 0.23537877198240262
# weighted_prob_node_right * w_i(right_node_data)): 0.15432098765432095 * 0.0 = 0.0
# column_index: 2, value: 5.6
# weighted_prob_node_left * w_i(left_node_data)): 0.8827160493827154 * 0.3408301834003571 = 0.30085627300154955
# weighted_prob_node_right * w_i(right_node_data)): 0.11728395061728393 * 0.0 = 0.0
# column_index: 2, value: 5.7
# weighted_prob_node_left * w_i(left_node_data)): 0.9012345679012339 * 0.3700137783069486 = 0.3334692076099658
# weighted_prob_node_right * w_i(right_node_data)): 0.09876543209876541 * 0.0 = 0.0
# column_index: 2, value: 5.8
# weighted_prob_node_left * w_i(left_node_data)): 0.9197530864197525 * 0.397128497657236 = 0.3652601614254823
# weighted_prob_node_right * w_i(right_node_data)): 0.0802469135802469 * 0.0 = 0.0
# column_index: 2, value: 5.9
# weighted_prob_node_left * w_i(left_node_data)): 0.932098765432098 * 0.41387263364285154 = 0.38577017086463294
# weighted_prob_node_right * w_i(right_node_data)): 0.06790123456790122 * 0.0 = 0.0
# column_index: 2, value: 6.0
# weighted_prob_node_left * w_i(left_node_data)): 0.9444444444444438 * 0.4294576919107893 = 0.4055989312490785
# weighted_prob_node_right * w_i(right_node_data)): 0.055555555555555546 * 0.0 = 0.0
# column_index: 2, value: 6.1
# weighted_prob_node_left * w_i(left_node_data)): 0.9629629629629621 * 0.45054740159656503 = 0.4338604607966919
# weighted_prob_node_right * w_i(right_node_data)): 0.03703703703703703 * 0.0 = 0.0
# column_index: 2, value: 6.3
# weighted_prob_node_left * w_i(left_node_data)): 0.969135802469135 * 0.45695100102776376 = 0.44284757507011635
# weighted_prob_node_right * w_i(right_node_data)): 0.030864197530864192 * 0.0 = 0.0
# column_index: 2, value: 6.4
# weighted_prob_node_left * w_i(left_node_data)): 0.9753086419753078 * 0.463038009156288 = 0.4516049718931694
# weighted_prob_node_right * w_i(right_node_data)): 0.024691358024691353 * 0.0 = 0.0
# column_index: 2, value: 6.6
# weighted_prob_node_left * w_i(left_node_data)): 0.9814814814814805 * 0.4688079075698064 = 0.46012627965184655
# weighted_prob_node_right * w_i(right_node_data)): 0.018518518518518514 * 0.0 = 0.0
# column_index: 2, value: 6.7
# weighted_prob_node_left * w_i(left_node_data)): 0.9938271604938262 * 0.4793989180181506 = 0.4764396654377912
# weighted_prob_node_right * w_i(right_node_data)): 0.006172839506172838 * 0.0 = 0.0
# column_index: 2, value: 6.9
# weighted_prob_node_left * w_i(left_node_data)): 0.999999999999999 * 0.484223410443281 = 0.4842234104432805
# weighted_prob_node_right * w_i(right_node_data)): 0.0 * 1.0 = 0.0
# column_index: 3, value: 0.1
# weighted_prob_node_left * w_i(left_node_data)): 0.0037037037037037025 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9962962962962953 * 0.47735171834289314 = 0.4755837490156968
# column_index: 3, value: 0.2
# weighted_prob_node_left * w_i(left_node_data)): 0.02098765432098764 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9790123456790114 * 0.4554096515842374 = 0.4458516712423456
# column_index: 3, value: 0.3
# weighted_prob_node_left * w_i(left_node_data)): 0.02530864197530862 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9746913580246904 * 0.45299089433921014 = 0.44152630997630377
# column_index: 3, value: 0.4
# weighted_prob_node_left * w_i(left_node_data)): 0.029629629629629596 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9703703703703694 * 0.45191837136605206 = 0.4385281973996501
# column_index: 3, value: 0.5
# weighted_prob_node_left * w_i(left_node_data)): 0.03024691358024688 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9697530864197522 * 0.4518764819439043 = 0.4382086130456006
# column_index: 3, value: 0.6
# weighted_prob_node_left * w_i(left_node_data)): 0.03086419753086416 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9691358024691349 * 0.4518625170868379 = 0.4379161431026758
# column_index: 3, value: 1.0
# weighted_prob_node_left * w_i(left_node_data)): 0.11975308641975302 * 0.4095541840185457 = 0.049045377592344334
# weighted_prob_node_right * w_i(right_node_data)): 0.8802469135802463 * 0.4858182481121146 = 0.4276400134616512
# column_index: 3, value: 1.1
# weighted_prob_node_left * w_i(left_node_data)): 0.1578483245149911 * 0.4952781517477227 = 0.07817882642225954
# weighted_prob_node_right * w_i(right_node_data)): 0.8421516754850084 * 0.4952562163810308 = 0.4170808524196509
# column_index: 3, value: 1.2
# weighted_prob_node_left * w_i(left_node_data)): 0.2213403880070545 * 0.45541985775157523 = 0.10080280802085123
# weighted_prob_node_right * w_i(right_node_data)): 0.7786596119929448 * 0.4993591036817947 = 0.3888307659180109
# column_index: 3, value: 1.3
# weighted_prob_node_left * w_i(left_node_data)): 0.38641975308641957 * 0.23239033424047006 = 0.08980021557687295
# weighted_prob_node_right * w_i(right_node_data)): 0.6135802469135796 * 0.3931791446673455 = 0.2412469566662599
# column_index: 3, value: 1.4
# weighted_prob_node_left * w_i(left_node_data)): 0.48148148148148134 * 0.16481731122242138 = 0.07935648318116582
# weighted_prob_node_right * w_i(right_node_data)): 0.5185185185185179 * 0.25628952286205897 = 0.13289086370625264
# column_index: 3, value: 1.5
# weighted_prob_node_left * w_i(left_node_data)): 0.6208112874779538 * 0.11044689655467743 = 0.06856668004805368
# weighted_prob_node_right * w_i(right_node_data)): 0.37918871252204545 * 0.041016988041208124 = 0.015553178886877843
# column_index: 3, value: 1.6
# weighted_prob_node_left * w_i(left_node_data)): 0.6650793650793646 * 0.10095133631663888 = 0.0671406506613836
# weighted_prob_node_right * w_i(right_node_data)): 0.33492063492063456 * 0.007084258498234908 = 0.0023726643541707366
# column_index: 3, value: 1.7
# weighted_prob_node_left * w_i(left_node_data)): 0.709523809523809 * 0.10742978948833193 = 0.07622399349410212
# weighted_prob_node_right * w_i(right_node_data)): 0.29047619047619033 * 0.002027624321572663 = 0.0005889765886472971
# column_index: 3, value: 1.8
# weighted_prob_node_left * w_i(left_node_data)): 0.7901234567901229 * 0.1851494509988375 = 0.14629092424599496
# weighted_prob_node_right * w_i(right_node_data)): 0.2098765432098765 * 0.0 = 0.0
# column_index: 3, value: 1.9
# weighted_prob_node_left * w_i(left_node_data)): 0.8209876543209871 * 0.23579861332336116 = 0.19358775044448773
# weighted_prob_node_right * w_i(right_node_data)): 0.1790123456790123 * 0.0 = 0.0
# column_index: 3, value: 2.0
# weighted_prob_node_left * w_i(left_node_data)): 0.8580246913580241 * 0.2995603442141007 = 0.25703017188740723
# weighted_prob_node_right * w_i(right_node_data)): 0.14197530864197527 * 0.0 = 0.0
# column_index: 3, value: 2.1
# weighted_prob_node_left * w_i(left_node_data)): 0.8950617283950612 * 0.3604943915097022 = 0.32266473314139993
# weighted_prob_node_right * w_i(right_node_data)): 0.10493827160493825 * 0.0 = 0.0
# column_index: 3, value: 2.2
# weighted_prob_node_left * w_i(left_node_data)): 0.9135802469135796 * 0.38834492010889554 = 0.35478424800071917
# weighted_prob_node_right * w_i(right_node_data)): 0.08641975308641973 * 0.0 = 0.0
# column_index: 3, value: 2.3
# weighted_prob_node_left * w_i(left_node_data)): 0.9629629629629621 * 0.45054740159656503 = 0.4338604607966919
# weighted_prob_node_right * w_i(right_node_data)): 0.03703703703703703 * 0.0 = 0.0
# column_index: 3, value: 2.4
# weighted_prob_node_left * w_i(left_node_data)): 0.9814814814814805 * 0.4688079075698064 = 0.46012627965184655
# weighted_prob_node_right * w_i(right_node_data)): 0.018518518518518514 * 0.0 = 0.0
# column_index: 3, value: 2.5
# weighted_prob_node_left * w_i(left_node_data)): 0.999999999999999 * 0.484223410443281 = 0.4842234104432805
# weighted_prob_node_right * w_i(right_node_data)): 0.0 * 1.0 = 0.0
# split_column_index: 3, split_value: 1.6
# Change in overall_metric: 0.06951331501555433
# Left leaf: Iris-setosa, Right leaf: Iris-virginica
# Boost Called
# Learner error: 0.6596119929453261
# Learner weight: 0.031581572050299433
# 3: Sample weight(sum) 0.9999999999999999
# Total stumps: 4

# %%
predictions = clf.predict(df.iloc[:, :-1].values)
# Out:
# Predict called

# %%
accuracy_score_classification(df.iloc[:, -1].values, predictions[:, -1])
# Out:
# 0.88
