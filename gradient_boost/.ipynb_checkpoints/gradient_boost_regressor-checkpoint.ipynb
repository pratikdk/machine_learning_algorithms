# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("Iris.csv")
df = df.drop("Id", axis=1)
df = df.rename(columns={"species": "label"})

# %%
# regressor = DecisionTreeClassifier(min_samples_leaf=15, min_samples_split=100)
# regressor.fit(df.iloc[:, :-1].values, df.iloc[:, -1].values)

# %%
# regressor.tree_.feature

# %%
# regressor.tree_.threshold

# %%
# df.head()

# %%
def get_potential_splits(data):
    """
    Get all potential splits for each feature
    Splits can be made on each unique value
    Can essentially make a split at each unique value

    """
    potential_splits = {}
    _, n_columns = data.shape
    for column_index in range(n_columns - 1): # excluding the last column which is the label
        values = data[:, column_index]
        unique_values = np.unique(values)

        potential_splits[column_index] = unique_values

    return potential_splits

# %%
def f_gini(data):
    label_column = data[:, -2]
    data_sample_weight =  data[:, -1]
    _, value_indexes, counts = np.unique(label_column, return_counts=True, return_index=True)
    # Get summed weights for each class
    class_weights = np.array([np.take(data_sample_weight, np.where(label_column == label_column[value_index])[0]).sum() for value_index in value_indexes])

    weighted_classes = counts * class_weights
    normalized_weighted_classes = weighted_classes / sum(weighted_classes)
    #return 1.0 - (np.sum(counts**2) / np.sum(class_weights)**2)
    return 1.0 - sum(normalized_weighted_classes**2)

# %%
def gini_sk(data):
    if len(data) <= 0:
        return None
    label_column = data[:, -2]
    data_sample_weight =  data[:, -1]
    _, value_indexes, counts = np.unique(label_column, return_counts=True, return_index=True)
    #print(f"labels: {label_column}")
    #print(f"For jizz: {[np.take(data_sample_weight, np.where(label_column == label_column[value_index])[0]) for value_index in value_indexes]}")
    class_weights = np.array([np.take(data_sample_weight, np.where(label_column == label_column[value_index])[0]).sum() for value_index in value_indexes])
#     cw = np.sum(class_weights**2)
#     wn = np.sum(data_sample_weight)**2

    #gini = 1.0 - (cw/wn)
    cw = np.sum(class_weights**2)
    wn = np.sum(data_sample_weight)**2
    gini = 1.0 - (cw/wn)
    print(f"cw: {cw}, wn: {wn} ---> 1.0 - (cw/wn) == {1.0} - {cw}/{wn}")
    return gini

# %%
def calculate_entropy(data_group):
    if len(data) <= 0:
        return None
    _, counts = np.unique(data_group[:, -2], return_counts=True)
    
    probabilities = counts / counts.sum()
    entropy = sum(probabilities * -np.log2(probabilities))
    
    return entropy

# %%
# def gini(data):
#     label_column = data[:, -2]
#     data_sample_weight =  data[:, -1]
#     _, value_indexes, counts = np.unique(label_column, return_counts=True, return_index=True)
#     # Get summed weights for each class
#     class_weights = np.array([np.take(data_sample_weight, np.where(label_column == label_column[value_index])[0]).sum() for value_index in value_indexes])

#     weighted_classes = counts * class_weights
#     normalized_weighted_classes = weighted_classes / sum(weighted_classes)
#     #return 1.0 - (np.sum(counts**2) / np.sum(class_weights)**2)
#     #return 1.0 - sum(normalized_weighted_classes**2)
    
#     #_, value_indexes, counts = np.unique(data, return_counts=True, return_index=True)
#     gini = len(counts)
#     for count in counts:
#         gini *= (count/len(data))
#     return gini

# %%
def gini(data):
    label_column = data[:, -2]
    data_sample_weight =  data[:, -1]
    _, value_indexes, counts = np.unique(label_column, return_counts=True, return_index=True)
    # Get summed weights for each class
    class_weights = np.array([np.take(data_sample_weight, np.where(label_column == label_column[value_index])[0]).sum() for value_index in value_indexes])

    weighted_classes = counts * class_weights
    normalized_weighted_classes = weighted_classes / sum(weighted_classes)
    #return 1.0 - (np.sum(counts**2) / np.sum(class_weights)**2)
    #return 1.0 - sum(normalized_weighted_classes**2)
    
    #_, value_indexes, counts = np.unique(data, return_counts=True, return_index=True)
    gini = len(counts)
    for count, class_weight in zip(counts, class_weights):
        gini *= (class_weight)
    return gini

# %%
def calculate_weighted_overall_metric(data, left_node_data, right_node_data, ml_task, metric_function):
    """
    Generalized impurity metric, computes weighted overall
    impurity/error w.r.t left and right nodes
    """
    # Labels
    left_label_column = left_node_data[:, -2]
    right_label_column = right_node_data[:, -2]
    parent_label_column = data[:, -2]
    # Sample weights
    left_sample_weight = left_node_data[:, -1]
    right_sample_weight = right_node_data[:, -1]
    parent_sample_weight = data[:, -1]

    if ml_task == 'classification':
        _, left_value_indexes, left_counts = np.unique(left_label_column, return_counts=True, return_index=True)
        _, right_value_indexes, right_counts = np.unique(right_label_column, return_counts=True, return_index=True)
        _, parent_value_indexes, parent_counts = np.unique(parent_label_column, return_counts=True, return_index=True)

        left_class_weights = np.array([np.take(left_sample_weight, np.where(left_label_column == left_label_column[value_index])[0]).sum() for value_index in left_value_indexes])
        right_class_weights = np.array([np.take(right_sample_weight, np.where(right_label_column == right_label_column[value_index])[0]).sum() for value_index in right_value_indexes])
        parent_class_weights = np.array([np.take(parent_sample_weight, np.where(parent_label_column == parent_label_column[value_index])[0]).sum() for value_index in parent_value_indexes])

        # class count * class weight, for respective classes
        left_weighted_classes = left_counts * left_class_weights
        right_weighted_classes = right_counts * right_class_weights
        parent_weighted_classes = parent_counts * parent_class_weights

#             weighted_prob_node_left = np.divide(np.sum(left_weighted_classes), np.sum(parent_weighted_classes))
#             weighted_prob_node_right = np.divide(np.sum(right_weighted_classes), np.sum(parent_weighted_classes))

        #weighted_prob_node_left = np.sum(left_weighted_classes / np.sum(parent_class_weights))
        #weighted_prob_node_right = np.sum(right_weighted_classes / np.sum(parent_class_weights))

        weighted_prob_node_left = np.sum(left_class_weights)# / np.sum(parent_weighted_classes)
        weighted_prob_node_right = np.sum(right_class_weights)# / np.sum(parent_weighted_classes)

    else:
        total_parent_sample_weight = np.sum(np.sum(left_sample_weight), np.sum(right_sample_weight))
        # Weighted probabilities of left and right node
        weighted_prob_node_left = np.sum(left_sample_weight) / total_parent_sample_weight
        weighted_prob_node_right = np.sum(right_sample_weight) / total_parent_sample_weight
    
    left_impurity = metric_function(left_node_data)
    right_impurity = metric_function(right_node_data)
    
    if left_impurity != None and right_impurity != None:
        overall_metric =  weighted_prob_node_left * left_impurity + weighted_prob_node_right * right_impurity

        # Compute final overall metric
        #print(f'Left gini: {metric_function(left_node_data)}, Right gini: {metric_function(right_node_data)}')
        #overall_metric = (weighted_prob_node_left * metric_function(left_node_data)) + (weighted_prob_node_right * metric_function(right_node_data))
        print(f'weighted_prob_node_left * w_i(left_node_data)): {weighted_prob_node_left} * {left_impurity} = {(weighted_prob_node_left * left_impurity)}')
        print(f'weighted_prob_node_right * w_i(right_node_data)): {weighted_prob_node_right} * {right_impurity} = {(weighted_prob_node_right * right_impurity)}')
        return overall_metric
    else:
        return None

# %%
def information_gain(parent_data_group, left_data_group, right_data_group, metric_function):
    
    # Calculate entropy for parent and left, right nodes
    parent_group_entropy = metric_function(parent_data_group)
    left_group_entropy = metric_function(left_data_group)
    right_group_entropy = metric_function(right_data_group)
    
    # Probabilities of left and right node
    num_examples_parent = len(parent_data_group)
    left_group_probability = len(left_data_group) / num_examples_parent
    right_group_probability = len(right_data_group) / num_examples_parent
    
    # Final equation for IG computation
    gain =  left_group_probability * metric_function(left_data_group) + right_group_probability * metric_function(right_data_group)
    
    return gain

# %%
def determine_type_of_feature(X):
    """
    Determine, if the feature is categorical or continuous
    """
    feature_types = []
    n_unique_values_treshold = 15 # Threshold for a numeric feature to be categorical

    n_samples, n_features = np.shape(X)

    for feature_i in range(n_features):
        unique_values = np.unique(X[:, feature_i])
        example_value = unique_values[0]

        if (isinstance(example_value, str)) or (len(unique_values) <= n_unique_values_treshold):
            feature_types.append("categorical")
        else:
            feature_types.append("continuous")

    return feature_types

# %%
def split_data(data, split_column_index, split_value):
    """ 
    Split data(examples) based on best split_column_index and split_value
    estimated using task specific splitting metric.
    """
    # Get values(from feature column) for the passed split_column index
    split_column_values = data[:, split_column_index]

    type_of_feature = feature_types[split_column_index]
    if type_of_feature == "continuous":
        print(f"Feature Type(Cont): {type_of_feature}")
        left_node_data = data[split_column_values <= split_value]
        right_node_data = data[split_column_values >  split_value]

    # feature is categorical   
    else:
        print(f"Feature Type(Cat): {type_of_feature}")
        left_node_data = data[split_column_values == split_value]
        right_node_data = data[split_column_values != split_value]
    return left_node_data, right_node_data

# %%
def determine_best_split(data, sample_weight, potential_splits, ml_task):
    """
    Iterate over each column_index (as keys) in potential_split (dict)
    Perform split(of examples) over each unique value and evaluate the split
    Identify the best split and return its feature index and value
    """
    # Stitch data with sample_weight towards the end
    data = np.concatenate((data, np.expand_dims(sample_weight, axis=1)), axis=1)

    # Best minimum gini index to be updated iteratively
    best_overall_metric = float('inf')

    for column_index in potential_splits:
        print(f"COLUMN {column_index}")
        for value in potential_splits[column_index]:
            print(f'column_index: {column_index}, value: {value}')
            left_node_data, right_node_data = split_data(data, split_column_index=column_index, split_value=value)

            if ml_task == "regression":
                current_overall_metric = calculate_weighted_overall_metric(data, left_node_data, right_node_data, ml_task,
                                                                                 metric_function=calculate_weighted_mse)
            else: # classification
                current_overall_metric = calculate_weighted_overall_metric(data, left_node_data, right_node_data, ml_task,
                                                                                 metric_function=gini_sk)
#             else: # classification
#                 #print("ran")
#                 current_overall_metric = information_gain(data, left_node_data, right_node_data, metric_function=calculate_entropy)
            if column_index == 0 and value == 4.4:
                print(left_node_data)
            # If a lower overall_metric is achieved update the index and value with the current
            if current_overall_metric != None and current_overall_metric <= best_overall_metric:
                best_overall_metric = current_overall_metric
                best_split_column_index = column_index
                best_split_value = value
            #print(f'best_overall_metric: {best_overall_metric}')
            #print('---')
        #print(f'Debug [1]: Best: {best_overall_metric}, index: {best_split_column_index}, value: {best_split_value}')
    return best_split_column_index, best_split_value, best_overall_metric

# %%
X = df.iloc[:, :-1].values

# %%
Y = df.iloc[:, -1].values

# %%
data = np.concatenate((X, np.expand_dims(Y, axis=1)), axis=1)

# %%
#global feature_types
feature_types = determine_type_of_feature(data)

# %%
sample_weight = np.full(len(data), np.divide(1, len(data))) 
potential_splits = get_potential_splits(data)
split_column_index, split_value, metric = determine_best_split(data, sample_weight, potential_splits, "classification")
# Out:
# COLUMN 0
# column_index: 0, value: 4.3
# Feature Type(Cont): continuous
# cw: 4.444444444444445e-05, wn: 4.444444444444445e-05 ---> 1.0 - (cw/wn) == 1.0 - 4.444444444444445e-05/4.444444444444445e-05
# cw: 0.32893333333333263, wn: 0.9867111111111161 ---> 1.0 - (cw/wn) == 1.0 - 0.32893333333333263/0.9867111111111161
# weighted_prob_node_left * w_i(left_node_data)): 0.006666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9933333333333323 * 0.6666366379892821 = 0.6621923937360195
# column_index: 0, value: 4.4
# Feature Type(Cont): continuous
# cw: 0.0007111111111111113, wn: 0.0007111111111111113 ---> 1.0 - (cw/wn) == 1.0 - 0.0007111111111111113/0.0007111111111111113
# cw: 0.31626666666666603, wn: 0.9473777777777824 ---> 1.0 - (cw/wn) == 1.0 - 0.31626666666666603/0.9473777777777824
# weighted_prob_node_left * w_i(left_node_data)): 0.02666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9733333333333323 * 0.6661662600863225 = 0.6484018264840199
# [[4.4 2.9 1.4 0.2 'Iris-setosa' 0.006666666666666667]
#  [4.3 3.0 1.1 0.1 'Iris-setosa' 0.006666666666666667]
#  [4.4 3.0 1.3 0.2 'Iris-setosa' 0.006666666666666667]
#  [4.4 3.2 1.3 0.2 'Iris-setosa' 0.006666666666666667]]
# column_index: 0, value: 4.5
# Feature Type(Cont): continuous
# cw: 0.0011111111111111111, wn: 0.0011111111111111111 ---> 1.0 - (cw/wn) == 1.0 - 0.0011111111111111111/0.0011111111111111111
# cw: 0.3122222222222216, wn: 0.934444444444449 ---> 1.0 - (cw/wn) == 1.0 - 0.3122222222222216/0.934444444444449
# weighted_prob_node_left * w_i(left_node_data)): 0.03333333333333333 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9666666666666657 * 0.6658739595719404 = 0.6436781609195418
# column_index: 0, value: 4.6
# Feature Type(Cont): continuous
# cw: 0.0036000000000000008, wn: 0.0036000000000000008 ---> 1.0 - (cw/wn) == 1.0 - 0.0036000000000000008/0.0036000000000000008
# cw: 0.2969333333333327, wn: 0.883600000000004 ---> 1.0 - (cw/wn) == 1.0 - 0.2969333333333327/0.883600000000004
# weighted_prob_node_left * w_i(left_node_data)): 0.060000000000000005 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9399999999999991 * 0.6639505055077735 = 0.6241134751773064
# column_index: 0, value: 4.7
# Feature Type(Cont): continuous
# cw: 0.005377777777777778, wn: 0.005377777777777778 ---> 1.0 - (cw/wn) == 1.0 - 0.005377777777777778/0.005377777777777778
# cw: 0.28982222222222165, wn: 0.858711111111115 ---> 1.0 - (cw/wn) == 1.0 - 0.28982222222222165/0.858711111111115
# weighted_prob_node_left * w_i(left_node_data)): 0.07333333333333333 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9266666666666659 * 0.6624915894622454 = 0.6139088729016802
# column_index: 0, value: 4.8
# Feature Type(Cont): continuous
# cw: 0.01137777777777778, wn: 0.01137777777777778 ---> 1.0 - (cw/wn) == 1.0 - 0.01137777777777778/0.01137777777777778
# cw: 0.27359999999999945, wn: 0.7980444444444478 ---> 1.0 - (cw/wn) == 1.0 - 0.27359999999999945/0.7980444444444478
# weighted_prob_node_left * w_i(left_node_data)): 0.10666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.8933333333333324 * 0.6571619514368477 = 0.5870646766169167
# column_index: 0, value: 4.9
# Feature Type(Cont): continuous
# cw: 0.017866666666666666, wn: 0.021511111111111102 ---> 1.0 - (cw/wn) == 1.0 - 0.017866666666666666/0.021511111111111102
# cw: 0.25342222222222177, wn: 0.7281777777777805 ---> 1.0 - (cw/wn) == 1.0 - 0.25342222222222177/0.7281777777777805
# weighted_prob_node_left * w_i(left_node_data)): 0.14666666666666664 * 0.16942148760330544 = 0.024848484848484793
# weighted_prob_node_right * w_i(right_node_data)): 0.8533333333333325 * 0.6519775390625019 = 0.5563541666666677
# column_index: 0, value: 5.0
# Feature Type(Cont): continuous
# cw: 0.03528888888888885, wn: 0.045511111111111044 ---> 1.0 - (cw/wn) == 1.0 - 0.03528888888888885/0.045511111111111044
# cw: 0.2263999999999996, wn: 0.6188444444444463 ---> 1.0 - (cw/wn) == 1.0 - 0.2263999999999996/0.6188444444444463
# weighted_prob_node_left * w_i(left_node_data)): 0.2133333333333332 * 0.22460937499999978 = 0.047916666666666594
# weighted_prob_node_right * w_i(right_node_data)): 0.786666666666666 * 0.6341568514794617 = 0.49887005649717603
# column_index: 0, value: 5.1
# Feature Type(Cont): continuous
# cw: 0.05835555555555546, wn: 0.07471111111111098 ---> 1.0 - (cw/wn) == 1.0 - 0.05835555555555546/0.07471111111111098
# cw: 0.20946666666666627, wn: 0.5280444444444456 ---> 1.0 - (cw/wn) == 1.0 - 0.20946666666666627/0.5280444444444456
# weighted_prob_node_left * w_i(left_node_data)): 0.2733333333333331 * 0.21891731112433066 = 0.05983739837398366
# weighted_prob_node_right * w_i(right_node_data)): 0.726666666666666 * 0.6033162191734719 = 0.4384097859327225
# column_index: 0, value: 5.2
# Feature Type(Cont): continuous
# cw: 0.06875555555555543, wn: 0.08999999999999983 ---> 1.0 - (cw/wn) == 1.0 - 0.06875555555555543/0.08999999999999983
# cw: 0.20208888888888848, wn: 0.4900000000000009 ---> 1.0 - (cw/wn) == 1.0 - 0.20208888888888848/0.4900000000000009
# weighted_prob_node_left * w_i(left_node_data)): 0.29999999999999977 * 0.23604938271604936 = 0.07081481481481475
# weighted_prob_node_right * w_i(right_node_data)): 0.6999999999999994 * 0.5875736961451263 = 0.41130158730158806
# column_index: 0, value: 5.3
# Feature Type(Cont): continuous
# cw: 0.07226666666666653, wn: 0.09404444444444426 ---> 1.0 - (cw/wn) == 1.0 - 0.07226666666666653/0.09404444444444426
# cw: 0.20115555555555517, wn: 0.4807111111111119 ---> 1.0 - (cw/wn) == 1.0 - 0.20115555555555517/0.4807111111111119
# weighted_prob_node_left * w_i(left_node_data)): 0.3066666666666664 * 0.2315689981096407 = 0.07101449275362309
# weighted_prob_node_right * w_i(right_node_data)): 0.6933333333333327 * 0.5815458579881672 = 0.4032051282051289
# column_index: 0, value: 5.4
# Feature Type(Cont): continuous
# cw: 0.09164444444444428, wn: 0.12017777777777752 ---> 1.0 - (cw/wn) == 1.0 - 0.09164444444444428/0.12017777777777752
# cw: 0.1938666666666663, wn: 0.42684444444444486 ---> 1.0 - (cw/wn) == 1.0 - 0.1938666666666663/0.42684444444444486
# weighted_prob_node_left * w_i(left_node_data)): 0.34666666666666635 * 0.23742603550295838 = 0.08230769230769217
# weighted_prob_node_right * w_i(right_node_data)): 0.6533333333333327 * 0.5458142440649743 = 0.3565986394557828
# column_index: 0, value: 5.5
# Feature Type(Cont): continuous
# cw: 0.1035999999999998, wn: 0.15471111111111074 ---> 1.0 - (cw/wn) == 1.0 - 0.1035999999999998/0.15471111111111074
# cw: 0.17471111111111076, wn: 0.36804444444444445 ---> 1.0 - (cw/wn) == 1.0 - 0.17471111111111076/0.36804444444444445
# weighted_prob_node_left * w_i(left_node_data)): 0.39333333333333304 * 0.33036483769031855 = 0.12994350282485853
# weighted_prob_node_right * w_i(right_node_data)): 0.6066666666666661 * 0.5252988769472295 = 0.318681318681319
# column_index: 0, value: 5.6
# Feature Type(Cont): continuous
# cw: 0.10973333333333314, wn: 0.18777777777777732 ---> 1.0 - (cw/wn) == 1.0 - 0.10973333333333314/0.18777777777777732
# cw: 0.1541777777777775, wn: 0.32111111111111085 ---> 1.0 - (cw/wn) == 1.0 - 0.1541777777777775/0.32111111111111085
# weighted_prob_node_left * w_i(left_node_data)): 0.433333333333333 * 0.41562130177514756 = 0.1801025641025638
# weighted_prob_node_right * w_i(right_node_data)): 0.5666666666666662 * 0.5198615916955023 = 0.2945882352941177
# column_index: 0, value: 5.7
# Feature Type(Cont): continuous
# cw: 0.1267111111111109, wn: 0.23684444444444383 ---> 1.0 - (cw/wn) == 1.0 - 0.1267111111111109/0.23684444444444383
# cw: 0.13559999999999978, wn: 0.26351111111111053 ---> 1.0 - (cw/wn) == 1.0 - 0.13559999999999978/0.26351111111111053
# weighted_prob_node_left * w_i(left_node_data)): 0.48666666666666636 * 0.4650028147870139 = 0.22630136986301327
# weighted_prob_node_right * w_i(right_node_data)): 0.5133333333333329 * 0.48541069320290076 = 0.24917748917748883
# column_index: 0, value: 5.8
# Feature Type(Cont): continuous
# cw: 0.13831111111111086, wn: 0.28444444444444394 ---> 1.0 - (cw/wn) == 1.0 - 0.13831111111111086/0.28444444444444394
# cw: 0.1160888888888887, wn: 0.2177777777777772 ---> 1.0 - (cw/wn) == 1.0 - 0.1160888888888887/0.2177777777777772
# weighted_prob_node_left * w_i(left_node_data)): 0.533333333333333 * 0.51375 = 0.27399999999999985
# weighted_prob_node_right * w_i(right_node_data)): 0.46666666666666634 * 0.4669387755102036 = 0.21790476190476152
# column_index: 0, value: 5.9
# Feature Type(Cont): continuous
# cw: 0.1433333333333331, wn: 0.30617777777777744 ---> 1.0 - (cw/wn) == 1.0 - 0.1433333333333331/0.30617777777777744
# cw: 0.10777777777777761, wn: 0.1995111111111106 ---> 1.0 - (cw/wn) == 1.0 - 0.10777777777777761/0.1995111111111106
# weighted_prob_node_left * w_i(left_node_data)): 0.5533333333333329 * 0.5318623893163017 = 0.29429718875502003
# weighted_prob_node_right * w_i(right_node_data)): 0.4466666666666663 * 0.45979059924259247 = 0.2053731343283578
# column_index: 0, value: 6.0
# Feature Type(Cont): continuous
# cw: 0.15471111111111083, wn: 0.3520444444444444 ---> 1.0 - (cw/wn) == 1.0 - 0.15471111111111083/0.3520444444444444
# cw: 0.09248888888888876, wn: 0.16537777777777737 ---> 1.0 - (cw/wn) == 1.0 - 0.09248888888888876/0.16537777777777737
# weighted_prob_node_left * w_i(left_node_data)): 0.5933333333333329 * 0.5605352859487446 = 0.33258426966292154
# weighted_prob_node_right * w_i(right_node_data)): 0.4066666666666664 * 0.4407417360924477 = 0.17923497267759528
# column_index: 0, value: 6.1
# Feature Type(Cont): continuous
# cw: 0.16786666666666636, wn: 0.40111111111111136 ---> 1.0 - (cw/wn) == 1.0 - 0.16786666666666636/0.40111111111111136
# cw: 0.07897777777777766, wn: 0.13444444444444414 ---> 1.0 - (cw/wn) == 1.0 - 0.07897777777777766/0.13444444444444414
# weighted_prob_node_left * w_i(left_node_data)): 0.6333333333333329 * 0.5814958448753473 = 0.3682807017543864
# weighted_prob_node_right * w_i(right_node_data)): 0.3666666666666665 * 0.412561983471074 = 0.15127272727272706
# column_index: 0, value: 6.2
# Feature Type(Cont): continuous
# cw: 0.1762222222222219, wn: 0.4356000000000005 ---> 1.0 - (cw/wn) == 1.0 - 0.1762222222222219/0.4356000000000005
# cw: 0.06955555555555545, wn: 0.11559999999999976 ---> 1.0 - (cw/wn) == 1.0 - 0.06955555555555545/0.11559999999999976
# weighted_prob_node_left * w_i(left_node_data)): 0.6599999999999995 * 0.5954494439342937 = 0.3929966329966335
# weighted_prob_node_right * w_i(right_node_data)): 0.3399999999999998 * 0.3983083429450208 = 0.135424836601307
# column_index: 0, value: 6.3
# Feature Type(Cont): continuous
# cw: 0.1947555555555552, wn: 0.5184000000000011 ---> 1.0 - (cw/wn) == 1.0 - 0.1947555555555552/0.5184000000000011
# cw: 0.048088888888888834, wn: 0.07839999999999986 ---> 1.0 - (cw/wn) == 1.0 - 0.048088888888888834/0.07839999999999986
# weighted_prob_node_left * w_i(left_node_data)): 0.7199999999999995 * 0.62431412894376 = 0.44950617283950695
# weighted_prob_node_right * w_i(right_node_data)): 0.27999999999999986 * 0.38662131519274334 = 0.10825396825396809
# column_index: 0, value: 6.4
# Feature Type(Cont): continuous
# cw: 0.21142222222222185, wn: 0.5877777777777794 ---> 1.0 - (cw/wn) == 1.0 - 0.21142222222222185/0.5877777777777794
# cw: 0.03364444444444442, wn: 0.05444444444444436 ---> 1.0 - (cw/wn) == 1.0 - 0.03364444444444442/0.05444444444444436
# weighted_prob_node_left * w_i(left_node_data)): 0.7666666666666659 * 0.6403024574669203 = 0.4908985507246384
# weighted_prob_node_right * w_i(right_node_data)): 0.23333333333333325 * 0.3820408163265301 = 0.089142857142857
# column_index: 0, value: 6.5
# Feature Type(Cont): continuous
# cw: 0.22435555555555514, wn: 0.640000000000002 ---> 1.0 - (cw/wn) == 1.0 - 0.22435555555555514/0.640000000000002
# cw: 0.024355555555555547, wn: 0.03999999999999995 ---> 1.0 - (cw/wn) == 1.0 - 0.024355555555555547/0.03999999999999995
# weighted_prob_node_left * w_i(left_node_data)): 0.7999999999999993 * 0.6494444444444463 = 0.5195555555555565
# weighted_prob_node_right * w_i(right_node_data)): 0.19999999999999998 * 0.39111111111111063 = 0.07822222222222212
# column_index: 0, value: 6.6
# Feature Type(Cont): continuous
# cw: 0.23199999999999957, wn: 0.6615111111111133 ---> 1.0 - (cw/wn) == 1.0 - 0.23199999999999957/0.6615111111111133
# cw: 0.023111111111111103, wn: 0.03484444444444441 ---> 1.0 - (cw/wn) == 1.0 - 0.023111111111111103/0.03484444444444441
# weighted_prob_node_left * w_i(left_node_data)): 0.8133333333333326 * 0.649287825853267 = 0.5280874316939901
# weighted_prob_node_right * w_i(right_node_data)): 0.18666666666666665 * 0.3367346938775505 = 0.06285714285714275
# column_index: 0, value: 6.7
# Feature Type(Cont): continuous
# cw: 0.2576888888888884, wn: 0.7511111111111141 ---> 1.0 - (cw/wn) == 1.0 - 0.2576888888888884/0.7511111111111141
# cw: 0.013244444444444446, wn: 0.017777777777777778 ---> 1.0 - (cw/wn) == 1.0 - 0.013244444444444446/0.017777777777777778
# weighted_prob_node_left * w_i(left_node_data)): 0.8666666666666659 * 0.6569230769230789 = 0.5693333333333346
# weighted_prob_node_right * w_i(right_node_data)): 0.13333333333333333 * 0.2549999999999999 = 0.03399999999999999
# column_index: 0, value: 6.8
# Feature Type(Cont): continuous
# cw: 0.26795555555555506, wn: 0.786177777777781 ---> 1.0 - (cw/wn) == 1.0 - 0.26795555555555506/0.786177777777781
# cw: 0.01017777777777778, wn: 0.012844444444444447 ---> 1.0 - (cw/wn) == 1.0 - 0.01017777777777778/0.012844444444444447
# weighted_prob_node_left * w_i(left_node_data)): 0.8866666666666658 * 0.6591667137769255 = 0.5844611528822067
# weighted_prob_node_right * w_i(right_node_data)): 0.11333333333333334 * 0.2076124567474048 = 0.02352941176470588
# column_index: 0, value: 6.9
# Feature Type(Cont): continuous
# cw: 0.2819999999999995, wn: 0.8341777777777815 ---> 1.0 - (cw/wn) == 1.0 - 0.2819999999999995/0.8341777777777815
# cw: 0.0064444444444444445, wn: 0.007511111111111112 ---> 1.0 - (cw/wn) == 1.0 - 0.0064444444444444445/0.007511111111111112
# weighted_prob_node_left * w_i(left_node_data)): 0.9133333333333324 * 0.661942564867603 = 0.6045742092457435
# weighted_prob_node_right * w_i(right_node_data)): 0.08666666666666667 * 0.1420118343195267 = 0.012307692307692313
# column_index: 0, value: 7.0
# Feature Type(Cont): continuous
# cw: 0.28639999999999943, wn: 0.8464000000000037 ---> 1.0 - (cw/wn) == 1.0 - 0.28639999999999943/0.8464000000000037
# cw: 0.0064, wn: 0.0064 ---> 1.0 - (cw/wn) == 1.0 - 0.0064/0.0064
# weighted_prob_node_left * w_i(left_node_data)): 0.919999999999999 * 0.6616257088846902 = 0.6086956521739143
# weighted_prob_node_right * w_i(right_node_data)): 0.08 * 0.0 = 0.0
# column_index: 0, value: 7.1
# Feature Type(Cont): continuous
# cw: 0.28982222222222165, wn: 0.858711111111115 ---> 1.0 - (cw/wn) == 1.0 - 0.28982222222222165/0.858711111111115
# cw: 0.005377777777777778, wn: 0.005377777777777778 ---> 1.0 - (cw/wn) == 1.0 - 0.005377777777777778/0.005377777777777778
# weighted_prob_node_left * w_i(left_node_data)): 0.9266666666666658 * 0.6624915894622454 = 0.6139088729016802
# weighted_prob_node_right * w_i(right_node_data)): 0.07333333333333333 * 0.0 = 0.0
# column_index: 0, value: 7.2
# Feature Type(Cont): continuous
# cw: 0.3006222222222216, wn: 0.896177777777782 ---> 1.0 - (cw/wn) == 1.0 - 0.3006222222222216/0.896177777777782
# cw: 0.002844444444444445, wn: 0.002844444444444445 ---> 1.0 - (cw/wn) == 1.0 - 0.002844444444444445/0.002844444444444445
# weighted_prob_node_left * w_i(left_node_data)): 0.9466666666666657 * 0.6645506843880205 = 0.6291079812206587
# weighted_prob_node_right * w_i(right_node_data)): 0.05333333333333334 * 0.0 = 0.0
# column_index: 0, value: 7.3
# Feature Type(Cont): continuous
# cw: 0.3043999999999994, wn: 0.9088444444444488 ---> 1.0 - (cw/wn) == 1.0 - 0.3043999999999994/0.9088444444444488
# cw: 0.002177777777777778, wn: 0.002177777777777778 ---> 1.0 - (cw/wn) == 1.0 - 0.002177777777777778/0.002177777777777778
# weighted_prob_node_left * w_i(left_node_data)): 0.9533333333333324 * 0.6650691965377302 = 0.6340326340326355
# weighted_prob_node_right * w_i(right_node_data)): 0.04666666666666667 * 0.0 = 0.0
# column_index: 0, value: 7.4
# Feature Type(Cont): continuous
# cw: 0.308266666666666, wn: 0.9216000000000044 ---> 1.0 - (cw/wn) == 1.0 - 0.308266666666666/0.9216000000000044
# cw: 0.0016, wn: 0.0016 ---> 1.0 - (cw/wn) == 1.0 - 0.0016/0.0016
# weighted_prob_node_left * w_i(left_node_data)): 0.9599999999999991 * 0.6655092592592615 = 0.6388888888888904
# weighted_prob_node_right * w_i(right_node_data)): 0.04 * 0.0 = 0.0
# column_index: 0, value: 7.6
# Feature Type(Cont): continuous
# cw: 0.3122222222222216, wn: 0.934444444444449 ---> 1.0 - (cw/wn) == 1.0 - 0.3122222222222216/0.934444444444449
# cw: 0.0011111111111111111, wn: 0.0011111111111111111 ---> 1.0 - (cw/wn) == 1.0 - 0.0011111111111111111/0.0011111111111111111
# weighted_prob_node_left * w_i(left_node_data)): 0.9666666666666657 * 0.6658739595719404 = 0.6436781609195418
# weighted_prob_node_right * w_i(right_node_data)): 0.03333333333333333 * 0.0 = 0.0
# column_index: 0, value: 7.7
# Feature Type(Cont): continuous
# cw: 0.32893333333333263, wn: 0.9867111111111161 ---> 1.0 - (cw/wn) == 1.0 - 0.32893333333333263/0.9867111111111161
# cw: 4.444444444444445e-05, wn: 4.444444444444445e-05 ---> 1.0 - (cw/wn) == 1.0 - 4.444444444444445e-05/4.444444444444445e-05
# weighted_prob_node_left * w_i(left_node_data)): 0.9933333333333323 * 0.6666366379892821 = 0.6621923937360195
# weighted_prob_node_right * w_i(right_node_data)): 0.006666666666666667 * 0.0 = 0.0
# column_index: 0, value: 7.9
# Feature Type(Cont): continuous
# cw: 0.33333333333333265, wn: 1.0000000000000049 ---> 1.0 - (cw/wn) == 1.0 - 0.33333333333333265/1.0000000000000049
# COLUMN 1
# column_index: 1, value: 2.0
# Feature Type(Cont): continuous
# cw: 4.444444444444445e-05, wn: 4.444444444444445e-05 ---> 1.0 - (cw/wn) == 1.0 - 4.444444444444445e-05/4.444444444444445e-05
# cw: 0.32893333333333263, wn: 0.9867111111111161 ---> 1.0 - (cw/wn) == 1.0 - 0.32893333333333263/0.9867111111111161
# weighted_prob_node_left * w_i(left_node_data)): 0.006666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9933333333333323 * 0.6666366379892821 = 0.6621923937360195
# column_index: 1, value: 2.2
# Feature Type(Cont): continuous
# cw: 0.00044444444444444447, wn: 0.0007111111111111113 ---> 1.0 - (cw/wn) == 1.0 - 0.00044444444444444447/0.0007111111111111113
# cw: 0.3159999999999994, wn: 0.9473777777777824 ---> 1.0 - (cw/wn) == 1.0 - 0.3159999999999994/0.9473777777777824
# weighted_prob_node_left * w_i(left_node_data)): 0.02666666666666667 * 0.3750000000000001 = 0.010000000000000004
# weighted_prob_node_right * w_i(right_node_data)): 0.9733333333333324 * 0.6664477387877674 = 0.6486757990867597
# column_index: 1, value: 2.3
# Feature Type(Cont): continuous
# cw: 0.0016888888888888889, wn: 0.002844444444444445 ---> 1.0 - (cw/wn) == 1.0 - 0.0016888888888888889/0.002844444444444445
# cw: 0.2994666666666661, wn: 0.896177777777782 ---> 1.0 - (cw/wn) == 1.0 - 0.2994666666666661/0.896177777777782
# weighted_prob_node_left * w_i(left_node_data)): 0.05333333333333334 * 0.4062500000000001 = 0.021666666666666674
# weighted_prob_node_right * w_i(right_node_data)): 0.9466666666666658 * 0.6658401110890718 = 0.6303286384976541
# column_index: 1, value: 2.4
# Feature Type(Cont): continuous
# cw: 0.00368888888888889, wn: 0.005377777777777778 ---> 1.0 - (cw/wn) == 1.0 - 0.00368888888888889/0.005377777777777778
# cw: 0.2881333333333328, wn: 0.858711111111115 ---> 1.0 - (cw/wn) == 1.0 - 0.2881333333333328/0.858711111111115
# weighted_prob_node_left * w_i(left_node_data)): 0.07333333333333333 * 0.31404958677685935 = 0.02303030303030302
# weighted_prob_node_right * w_i(right_node_data)): 0.9266666666666658 * 0.6644583613684614 = 0.6157314148681069
# column_index: 1, value: 2.5
# Feature Type(Cont): continuous
# cw: 0.008666666666666666, wn: 0.016044444444444448 ---> 1.0 - (cw/wn) == 1.0 - 0.008666666666666666/0.016044444444444448
# cw: 0.2575555555555551, wn: 0.7627111111111141 ---> 1.0 - (cw/wn) == 1.0 - 0.2575555555555551/0.7627111111111141
# weighted_prob_node_left * w_i(left_node_data)): 0.12666666666666668 * 0.4598337950138506 = 0.058245614035087746
# weighted_prob_node_right * w_i(right_node_data)): 0.8733333333333325 * 0.6623157158673756 = 0.5784223918575074
# column_index: 1, value: 2.6
# Feature Type(Cont): continuous
# cw: 0.013600000000000003, wn: 0.025599999999999984 ---> 1.0 - (cw/wn) == 1.0 - 0.013600000000000003/0.025599999999999984
# cw: 0.2402666666666662, wn: 0.7056000000000026 ---> 1.0 - (cw/wn) == 1.0 - 0.2402666666666662/0.7056000000000026
# weighted_prob_node_left * w_i(left_node_data)): 0.16 * 0.46874999999999956 = 0.07499999999999993
# weighted_prob_node_right * w_i(right_node_data)): 0.8399999999999992 * 0.6594860166288756 = 0.553968253968255
# column_index: 1, value: 2.7
# Feature Type(Cont): continuous
# cw: 0.025022222222222217, wn: 0.04839999999999993 ---> 1.0 - (cw/wn) == 1.0 - 0.025022222222222217/0.04839999999999993
# cw: 0.2116888888888885, wn: 0.6084000000000018 ---> 1.0 - (cw/wn) == 1.0 - 0.2116888888888885/0.6084000000000018
# weighted_prob_node_left * w_i(left_node_data)): 0.21999999999999997 * 0.48301193755739147 = 0.10626262626262611
# weighted_prob_node_right * w_i(right_node_data)): 0.7799999999999994 * 0.6520563956461409 = 0.5086039886039895
# column_index: 1, value: 2.8
# Feature Type(Cont): continuous
# cw: 0.04848888888888886, wn: 0.09817777777777759 ---> 1.0 - (cw/wn) == 1.0 - 0.04848888888888886/0.09817777777777759
# cw: 0.17293333333333305, wn: 0.4715111111111118 ---> 1.0 - (cw/wn) == 1.0 - 0.17293333333333305/0.4715111111111118
# weighted_prob_node_left * w_i(left_node_data)): 0.31333333333333324 * 0.506111362607514 = 0.15858156028368767
# weighted_prob_node_right * w_i(right_node_data)): 0.6866666666666662 * 0.6332359317560574 = 0.4348220064724925
# column_index: 1, value: 2.9
# Feature Type(Cont): continuous
# cw: 0.07115555555555547, wn: 0.14439999999999967 ---> 1.0 - (cw/wn) == 1.0 - 0.07115555555555547/0.14439999999999967
# cw: 0.15115555555555532, wn: 0.38440000000000013 ---> 1.0 - (cw/wn) == 1.0 - 0.15115555555555532/0.38440000000000013
# weighted_prob_node_left * w_i(left_node_data)): 0.3799999999999998 * 0.5072329947676202 = 0.19274853801169556
# weighted_prob_node_right * w_i(right_node_data)): 0.6199999999999996 * 0.6067753497514171 = 0.37620071684587836
# column_index: 1, value: 3.0
# Feature Type(Cont): continuous
# cw: 0.12964444444444423, wn: 0.30617777777777744 ---> 1.0 - (cw/wn) == 1.0 - 0.12964444444444423/0.30617777777777744
# cw: 0.09408888888888875, wn: 0.1995111111111106 ---> 1.0 - (cw/wn) == 1.0 - 0.09408888888888875/0.1995111111111106
# weighted_prob_node_left * w_i(left_node_data)): 0.5533333333333329 * 0.5765713456234579 = 0.31903614457831314
# weighted_prob_node_right * w_i(right_node_data)): 0.44666666666666643 * 0.5284027623078632 = 0.23601990049751212
# column_index: 1, value: 3.1
# Feature Type(Cont): continuous
# cw: 0.15835555555555528, wn: 0.40111111111111136 ---> 1.0 - (cw/wn) == 1.0 - 0.15835555555555528/0.40111111111111136
# cw: 0.06946666666666657, wn: 0.13444444444444414 ---> 1.0 - (cw/wn) == 1.0 - 0.06946666666666657/0.13444444444444414
# weighted_prob_node_left * w_i(left_node_data)): 0.6333333333333329 * 0.6052077562326879 = 0.38329824561403536
# weighted_prob_node_right * w_i(right_node_data)): 0.3666666666666665 * 0.4833057851239665 = 0.17721212121212096
# column_index: 1, value: 3.2
# Feature Type(Cont): continuous
# cw: 0.19519999999999965, wn: 0.5184000000000011 ---> 1.0 - (cw/wn) == 1.0 - 0.19519999999999965/0.5184000000000011
# cw: 0.04853333333333327, wn: 0.07839999999999986 ---> 1.0 - (cw/wn) == 1.0 - 0.04853333333333327/0.07839999999999986
# weighted_prob_node_left * w_i(left_node_data)): 0.7199999999999994 * 0.6234567901234582 = 0.44888888888888956
# weighted_prob_node_right * w_i(right_node_data)): 0.27999999999999986 * 0.3809523809523807 = 0.10666666666666655
# column_index: 1, value: 3.3
# Feature Type(Cont): continuous
# cw: 0.2144888888888885, wn: 0.5776000000000016 ---> 1.0 - (cw/wn) == 1.0 - 0.2144888888888885/0.5776000000000016
# cw: 0.04115555555555551, wn: 0.0575999999999999 ---> 1.0 - (cw/wn) == 1.0 - 0.04115555555555551/0.0575999999999999
# weighted_prob_node_left * w_i(left_node_data)): 0.7599999999999993 * 0.6286549707602356 = 0.47777777777777863
# weighted_prob_node_right * w_i(right_node_data)): 0.23999999999999985 * 0.28549382716049343 = 0.06851851851851838
# column_index: 1, value: 3.4
# Feature Type(Cont): continuous
# cw: 0.2466666666666662, wn: 0.7056000000000026 ---> 1.0 - (cw/wn) == 1.0 - 0.2466666666666662/0.7056000000000026
# cw: 0.019999999999999997, wn: 0.025599999999999984 ---> 1.0 - (cw/wn) == 1.0 - 0.019999999999999997/0.025599999999999984
# weighted_prob_node_left * w_i(left_node_data)): 0.8399999999999992 * 0.6504157218442952 = 0.5463492063492075
# weighted_prob_node_right * w_i(right_node_data)): 0.15999999999999998 * 0.21874999999999967 = 0.03499999999999994
# column_index: 1, value: 3.5
# Feature Type(Cont): continuous
# cw: 0.2637333333333328, wn: 0.7744000000000031 ---> 1.0 - (cw/wn) == 1.0 - 0.2637333333333328/0.7744000000000031
# cw: 0.010400000000000001, wn: 0.014400000000000003 ---> 1.0 - (cw/wn) == 1.0 - 0.010400000000000001/0.014400000000000003
# weighted_prob_node_left * w_i(left_node_data)): 0.8799999999999991 * 0.659435261707991 = 0.5803030303030315
# weighted_prob_node_right * w_i(right_node_data)): 0.12000000000000001 * 0.2777777777777778 = 0.03333333333333334
# column_index: 1, value: 3.6
# Feature Type(Cont): continuous
# cw: 0.274355555555555, wn: 0.8100000000000034 ---> 1.0 - (cw/wn) == 1.0 - 0.274355555555555/0.8100000000000034
# cw: 0.007688888888888889, wn: 0.010000000000000002 ---> 1.0 - (cw/wn) == 1.0 - 0.007688888888888889/0.010000000000000002
# weighted_prob_node_left * w_i(left_node_data)): 0.899999999999999 * 0.6612894375857359 = 0.5951604938271616
# weighted_prob_node_right * w_i(right_node_data)): 0.1 * 0.23111111111111127 = 0.023111111111111127
# column_index: 1, value: 3.7
# Feature Type(Cont): continuous
# cw: 0.28462222222222167, wn: 0.8464000000000037 ---> 1.0 - (cw/wn) == 1.0 - 0.28462222222222167/0.8464000000000037
# cw: 0.004622222222222222, wn: 0.0064 ---> 1.0 - (cw/wn) == 1.0 - 0.004622222222222222/0.0064
# weighted_prob_node_left * w_i(left_node_data)): 0.919999999999999 * 0.6637261079605146 = 0.6106280193236727
# weighted_prob_node_right * w_i(right_node_data)): 0.08 * 0.2777777777777778 = 0.022222222222222223
# column_index: 1, value: 3.8
# Feature Type(Cont): continuous
# cw: 0.308266666666666, wn: 0.9216000000000044 ---> 1.0 - (cw/wn) == 1.0 - 0.308266666666666/0.9216000000000044
# cw: 0.0016, wn: 0.0016 ---> 1.0 - (cw/wn) == 1.0 - 0.0016/0.0016
# weighted_prob_node_left * w_i(left_node_data)): 0.9599999999999991 * 0.6655092592592615 = 0.6388888888888904
# weighted_prob_node_right * w_i(right_node_data)): 0.04 * 0.0 = 0.0
# column_index: 1, value: 3.9
# Feature Type(Cont): continuous
# cw: 0.31626666666666603, wn: 0.9473777777777824 ---> 1.0 - (cw/wn) == 1.0 - 0.31626666666666603/0.9473777777777824
# cw: 0.0007111111111111113, wn: 0.0007111111111111113 ---> 1.0 - (cw/wn) == 1.0 - 0.0007111111111111113/0.0007111111111111113
# weighted_prob_node_left * w_i(left_node_data)): 0.9733333333333323 * 0.6661662600863225 = 0.6484018264840199
# weighted_prob_node_right * w_i(right_node_data)): 0.02666666666666667 * 0.0 = 0.0
# column_index: 1, value: 4.0
# Feature Type(Cont): continuous
# cw: 0.32039999999999935, wn: 0.9604000000000048 ---> 1.0 - (cw/wn) == 1.0 - 0.32039999999999935/0.9604000000000048
# cw: 0.0004, wn: 0.0004 ---> 1.0 - (cw/wn) == 1.0 - 0.0004/0.0004
# weighted_prob_node_left * w_i(left_node_data)): 0.9799999999999991 * 0.6663890045814267 = 0.6530612244897975
# weighted_prob_node_right * w_i(right_node_data)): 0.02 * 0.0 = 0.0
# column_index: 1, value: 4.1
# Feature Type(Cont): continuous
# cw: 0.3246222222222216, wn: 0.973511111111116 ---> 1.0 - (cw/wn) == 1.0 - 0.3246222222222216/0.973511111111116
# cw: 0.0001777777777777778, wn: 0.0001777777777777778 ---> 1.0 - (cw/wn) == 1.0 - 0.0001777777777777778/0.0001777777777777778
# weighted_prob_node_left * w_i(left_node_data)): 0.9866666666666657 * 0.6665449233016824 = 0.6576576576576593
# weighted_prob_node_right * w_i(right_node_data)): 0.013333333333333334 * 0.0 = 0.0
# column_index: 1, value: 4.2
# Feature Type(Cont): continuous
# cw: 0.32893333333333263, wn: 0.9867111111111161 ---> 1.0 - (cw/wn) == 1.0 - 0.32893333333333263/0.9867111111111161
# cw: 4.444444444444445e-05, wn: 4.444444444444445e-05 ---> 1.0 - (cw/wn) == 1.0 - 4.444444444444445e-05/4.444444444444445e-05
# weighted_prob_node_left * w_i(left_node_data)): 0.9933333333333323 * 0.6666366379892821 = 0.6621923937360195
# weighted_prob_node_right * w_i(right_node_data)): 0.006666666666666667 * 0.0 = 0.0
# column_index: 1, value: 4.4
# Feature Type(Cont): continuous
# cw: 0.33333333333333265, wn: 1.0000000000000049 ---> 1.0 - (cw/wn) == 1.0 - 0.33333333333333265/1.0000000000000049
# COLUMN 2
# column_index: 2, value: 1.0
# Feature Type(Cont): continuous
# cw: 4.444444444444445e-05, wn: 4.444444444444445e-05 ---> 1.0 - (cw/wn) == 1.0 - 4.444444444444445e-05/4.444444444444445e-05
# cw: 0.32893333333333263, wn: 0.9867111111111161 ---> 1.0 - (cw/wn) == 1.0 - 0.32893333333333263/0.9867111111111161
# weighted_prob_node_left * w_i(left_node_data)): 0.006666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9933333333333323 * 0.6666366379892821 = 0.6621923937360195
# column_index: 2, value: 1.1
# Feature Type(Cont): continuous
# cw: 0.0001777777777777778, wn: 0.0001777777777777778 ---> 1.0 - (cw/wn) == 1.0 - 0.0001777777777777778/0.0001777777777777778
# cw: 0.3246222222222216, wn: 0.973511111111116 ---> 1.0 - (cw/wn) == 1.0 - 0.3246222222222216/0.973511111111116
# weighted_prob_node_left * w_i(left_node_data)): 0.013333333333333334 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9866666666666657 * 0.6665449233016824 = 0.6576576576576593
# column_index: 2, value: 1.2
# Feature Type(Cont): continuous
# cw: 0.0007111111111111113, wn: 0.0007111111111111113 ---> 1.0 - (cw/wn) == 1.0 - 0.0007111111111111113/0.0007111111111111113
# cw: 0.31626666666666603, wn: 0.9473777777777824 ---> 1.0 - (cw/wn) == 1.0 - 0.31626666666666603/0.9473777777777824
# weighted_prob_node_left * w_i(left_node_data)): 0.02666666666666667 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9733333333333323 * 0.6661662600863225 = 0.6484018264840199
# column_index: 2, value: 1.3
# Feature Type(Cont): continuous
# cw: 0.005377777777777778, wn: 0.005377777777777778 ---> 1.0 - (cw/wn) == 1.0 - 0.005377777777777778/0.005377777777777778
# cw: 0.28982222222222165, wn: 0.858711111111115 ---> 1.0 - (cw/wn) == 1.0 - 0.28982222222222165/0.858711111111115
# weighted_prob_node_left * w_i(left_node_data)): 0.07333333333333333 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9266666666666659 * 0.6624915894622454 = 0.6139088729016802
# column_index: 2, value: 1.4
# Feature Type(Cont): continuous
# cw: 0.0235111111111111, wn: 0.0235111111111111 ---> 1.0 - (cw/wn) == 1.0 - 0.0235111111111111/0.0235111111111111
# cw: 0.25462222222222175, wn: 0.7168444444444471 ---> 1.0 - (cw/wn) == 1.0 - 0.25462222222222175/0.7168444444444471
# weighted_prob_node_left * w_i(left_node_data)): 0.1533333333333333 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.8466666666666658 * 0.6448012896025812 = 0.5459317585301848
# column_index: 2, value: 1.5
# Feature Type(Cont): continuous
# cw: 0.06084444444444434, wn: 0.06084444444444434 ---> 1.0 - (cw/wn) == 1.0 - 0.06084444444444434/0.06084444444444434
# cw: 0.22973333333333287, wn: 0.5675111111111125 ---> 1.0 - (cw/wn) == 1.0 - 0.22973333333333287/0.5675111111111125
# weighted_prob_node_left * w_i(left_node_data)): 0.24666666666666645 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.7533333333333326 * 0.5951914793640867 = 0.4483775811209449
# column_index: 2, value: 1.6
# Feature Type(Cont): continuous
# cw: 0.08604444444444428, wn: 0.08604444444444428 ---> 1.0 - (cw/wn) == 1.0 - 0.08604444444444428/0.08604444444444428
# cw: 0.22382222222222176, wn: 0.4993777777777787 ---> 1.0 - (cw/wn) == 1.0 - 0.22382222222222176/0.4993777777777787
# weighted_prob_node_left * w_i(left_node_data)): 0.29333333333333306 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.7066666666666659 * 0.5517977928088305 = 0.38993710691823974
# column_index: 2, value: 1.7
# Feature Type(Cont): continuous
# cw: 0.1023999999999998, wn: 0.1023999999999998 ---> 1.0 - (cw/wn) == 1.0 - 0.1023999999999998/0.1023999999999998
# cw: 0.22239999999999954, wn: 0.46240000000000064 ---> 1.0 - (cw/wn) == 1.0 - 0.22239999999999954/0.46240000000000064
# weighted_prob_node_left * w_i(left_node_data)): 0.3199999999999997 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.6799999999999993 * 0.5190311418685138 = 0.35294117647058904
# column_index: 2, value: 1.9
# Feature Type(Cont): continuous
# cw: 0.11111111111111088, wn: 0.11111111111111088 ---> 1.0 - (cw/wn) == 1.0 - 0.11111111111111088/0.11111111111111088
# cw: 0.22222222222222177, wn: 0.444444444444445 ---> 1.0 - (cw/wn) == 1.0 - 0.22222222222222177/0.444444444444445
# weighted_prob_node_left * w_i(left_node_data)): 0.333333333333333 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.666666666666666 * 0.5000000000000016 = 0.33333333333333404
# column_index: 2, value: 3.0
# Feature Type(Cont): continuous
# cw: 0.11115555555555533, wn: 0.11559999999999976 ---> 1.0 - (cw/wn) == 1.0 - 0.11115555555555533/0.11559999999999976
# cw: 0.21782222222222178, wn: 0.4356000000000005 ---> 1.0 - (cw/wn) == 1.0 - 0.21782222222222178/0.4356000000000005
# weighted_prob_node_left * w_i(left_node_data)): 0.33999999999999964 * 0.03844675124951935 = 0.013071895424836565
# weighted_prob_node_right * w_i(right_node_data)): 0.6599999999999993 * 0.4999489847974712 = 0.32996632996633063
# column_index: 2, value: 3.3
# Feature Type(Cont): continuous
# cw: 0.11151111111111088, wn: 0.12484444444444417 ---> 1.0 - (cw/wn) == 1.0 - 0.11151111111111088/0.12484444444444417
# cw: 0.20928888888888847, wn: 0.41817777777777815 ---> 1.0 - (cw/wn) == 1.0 - 0.20928888888888847/0.41817777777777815
# weighted_prob_node_left * w_i(left_node_data)): 0.353333333333333 * 0.10679957280170871 = 0.03773584905660371
# weighted_prob_node_right * w_i(right_node_data)): 0.6466666666666661 * 0.49952173450951365 = 0.3230240549828185
# column_index: 2, value: 3.5
# Feature Type(Cont): continuous
# cw: 0.11222222222222199, wn: 0.13444444444444414 ---> 1.0 - (cw/wn) == 1.0 - 0.11222222222222199/0.13444444444444414
# cw: 0.2011111111111107, wn: 0.40111111111111136 ---> 1.0 - (cw/wn) == 1.0 - 0.2011111111111107/0.40111111111111136
# weighted_prob_node_left * w_i(left_node_data)): 0.3666666666666663 * 0.165289256198347 = 0.06060606060606051
# weighted_prob_node_right * w_i(right_node_data)): 0.6333333333333326 * 0.4986149584487548 = 0.315789473684211
# column_index: 2, value: 3.6
# Feature Type(Cont): continuous
# cw: 0.11271111111111089, wn: 0.13937777777777746 ---> 1.0 - (cw/wn) == 1.0 - 0.11271111111111089/0.13937777777777746
# cw: 0.19715555555555517, wn: 0.3927111111111113 ---> 1.0 - (cw/wn) == 1.0 - 0.19715555555555517/0.3927111111111113
# weighted_prob_node_left * w_i(left_node_data)): 0.37333333333333296 * 0.1913265306122447 = 0.07142857142857129
# weighted_prob_node_right * w_i(right_node_data)): 0.626666666666666 * 0.4979628791308296 = 0.3120567375886529
# column_index: 2, value: 3.7
# Feature Type(Cont): continuous
# cw: 0.11328888888888866, wn: 0.14439999999999967 ---> 1.0 - (cw/wn) == 1.0 - 0.11328888888888866/0.14439999999999967
# cw: 0.1932888888888885, wn: 0.38440000000000013 ---> 1.0 - (cw/wn) == 1.0 - 0.1932888888888885/0.38440000000000013
# weighted_prob_node_left * w_i(left_node_data)): 0.37999999999999967 * 0.21545090797168331 = 0.0818713450292396
# weighted_prob_node_right * w_i(right_node_data)): 0.6199999999999994 * 0.49716730257833386 = 0.3082437275985667
# column_index: 2, value: 3.8
# Feature Type(Cont): continuous
# cw: 0.11395555555555532, wn: 0.14951111111111076 ---> 1.0 - (cw/wn) == 1.0 - 0.11395555555555532/0.14951111111111076
# cw: 0.18951111111111074, wn: 0.37617777777777783 ---> 1.0 - (cw/wn) == 1.0 - 0.18951111111111074/0.37617777777777783
# weighted_prob_node_left * w_i(left_node_data)): 0.3866666666666663 * 0.23781212841854915 = 0.0919540229885056
# weighted_prob_node_right * w_i(right_node_data)): 0.6133333333333327 * 0.49621928166351714 = 0.3043478260869569
# column_index: 2, value: 3.9
# Feature Type(Cont): continuous
# cw: 0.11648888888888866, wn: 0.16537777777777737 ---> 1.0 - (cw/wn) == 1.0 - 0.11648888888888866/0.16537777777777737
# cw: 0.17871111111111077, wn: 0.3520444444444444 ---> 1.0 - (cw/wn) == 1.0 - 0.17871111111111077/0.3520444444444444
# weighted_prob_node_left * w_i(left_node_data)): 0.4066666666666663 * 0.29561945713517845 = 0.12021857923497246
# weighted_prob_node_right * w_i(right_node_data)): 0.5933333333333328 * 0.49236207549551914 = 0.2921348314606744
# column_index: 2, value: 4.0
# Feature Type(Cont): continuous
# cw: 0.12248888888888866, wn: 0.19359999999999952 ---> 1.0 - (cw/wn) == 1.0 - 0.12248888888888866/0.19359999999999952
# cw: 0.16248888888888857, wn: 0.3135999999999997 ---> 1.0 - (cw/wn) == 1.0 - 0.16248888888888857/0.3135999999999997
# weighted_prob_node_left * w_i(left_node_data)): 0.43999999999999967 * 0.36730945821854877 = 0.16161616161616132
# weighted_prob_node_right * w_i(right_node_data)): 0.5599999999999995 * 0.4818594104308396 = 0.26984126984126994
# column_index: 2, value: 4.1
# Feature Type(Cont): continuous
# cw: 0.12715555555555533, wn: 0.21159999999999946 ---> 1.0 - (cw/wn) == 1.0 - 0.12715555555555533/0.21159999999999946
# cw: 0.15382222222222194, wn: 0.2915999999999996 ---> 1.0 - (cw/wn) == 1.0 - 0.15382222222222194/0.2915999999999996
# weighted_prob_node_left * w_i(left_node_data)): 0.45999999999999963 * 0.3990758244066368 = 0.1835748792270528
# weighted_prob_node_right * w_i(right_node_data)): 0.5399999999999995 * 0.4724889498552052 = 0.25514403292181054
# column_index: 2, value: 4.2
# Feature Type(Cont): continuous
# cw: 0.13462222222222198, wn: 0.23684444444444383 ---> 1.0 - (cw/wn) == 1.0 - 0.13462222222222198/0.23684444444444383
# cw: 0.14351111111111087, wn: 0.26351111111111053 ---> 1.0 - (cw/wn) == 1.0 - 0.14351111111111087/0.26351111111111053
# weighted_prob_node_left * w_i(left_node_data)): 0.48666666666666625 * 0.43160067554888304 = 0.21004566210045622
# weighted_prob_node_right * w_i(right_node_data)): 0.5133333333333329 * 0.45538876707707854 = 0.23376623376623343
# column_index: 2, value: 4.3
# Feature Type(Cont): continuous
# cw: 0.13888888888888865, wn: 0.24999999999999933 ---> 1.0 - (cw/wn) == 1.0 - 0.13888888888888865/0.24999999999999933
# cw: 0.13888888888888865, wn: 0.24999999999999933 ---> 1.0 - (cw/wn) == 1.0 - 0.13888888888888865/0.24999999999999933
# weighted_prob_node_left * w_i(left_node_data)): 0.49999999999999956 * 0.444444444444444 = 0.2222222222222218
# weighted_prob_node_right * w_i(right_node_data)): 0.49999999999999956 * 0.444444444444444 = 0.2222222222222218
# column_index: 2, value: 4.4
# Feature Type(Cont): continuous
# cw: 0.14848888888888861, wn: 0.2773777777777773 ---> 1.0 - (cw/wn) == 1.0 - 0.14848888888888861/0.2773777777777773
# cw: 0.1307111111111109, wn: 0.22404444444444385 ---> 1.0 - (cw/wn) == 1.0 - 0.1307111111111109/0.22404444444444385
# weighted_prob_node_left * w_i(left_node_data)): 0.5266666666666662 * 0.4646691235378946 = 0.24472573839662426
# weighted_prob_node_right * w_i(right_node_data)): 0.47333333333333294 * 0.4165840111089064 = 0.19718309859154887
# column_index: 2, value: 4.5
# Feature Type(Cont): continuous
# cw: 0.16875555555555524, wn: 0.3363999999999998 ---> 1.0 - (cw/wn) == 1.0 - 0.16875555555555524/0.3363999999999998
# cw: 0.11542222222222201, wn: 0.17639999999999956 ---> 1.0 - (cw/wn) == 1.0 - 0.11542222222222201/0.17639999999999956
# weighted_prob_node_left * w_i(left_node_data)): 0.5799999999999995 * 0.49834852688598297 = 0.28904214559386987
# weighted_prob_node_right * w_i(right_node_data)): 0.41999999999999965 * 0.34567901234567855 = 0.14518518518518486
# column_index: 2, value: 4.6
# Feature Type(Cont): continuous
# cw: 0.17875555555555522, wn: 0.36 ---> 1.0 - (cw/wn) == 1.0 - 0.17875555555555522/0.36
# cw: 0.11208888888888867, wn: 0.15999999999999961 ---> 1.0 - (cw/wn) == 1.0 - 0.11208888888888867/0.15999999999999961
# weighted_prob_node_left * w_i(left_node_data)): 0.5999999999999995 * 0.5034567901234577 = 0.3020740740740744
# weighted_prob_node_right * w_i(right_node_data)): 0.3999999999999997 * 0.2994444444444442 = 0.11977777777777758
# column_index: 2, value: 4.7
# Feature Type(Cont): continuous
# cw: 0.19719999999999963, wn: 0.40111111111111136 ---> 1.0 - (cw/wn) == 1.0 - 0.19719999999999963/0.40111111111111136
# cw: 0.1083111111111109, wn: 0.13444444444444414 ---> 1.0 - (cw/wn) == 1.0 - 0.1083111111111109/0.13444444444444414
# weighted_prob_node_left * w_i(left_node_data)): 0.6333333333333327 * 0.5083656509695303 = 0.32196491228070223
# weighted_prob_node_right * w_i(right_node_data)): 0.3666666666666663 * 0.19438016528925595 = 0.07127272727272711
# column_index: 2, value: 4.8
# Feature Type(Cont): continuous
# cw: 0.20555555555555516, wn: 0.4356000000000005 ---> 1.0 - (cw/wn) == 1.0 - 0.20555555555555516/0.4356000000000005
# cw: 0.09888888888888869, wn: 0.11559999999999976 ---> 1.0 - (cw/wn) == 1.0 - 0.09888888888888869/0.11559999999999976
# weighted_prob_node_left * w_i(left_node_data)): 0.6599999999999994 * 0.5281093765942265 = 0.34855218855218917
# weighted_prob_node_right * w_i(right_node_data)): 0.3399999999999997 * 0.14455978469819286 = 0.04915032679738553
# column_index: 2, value: 4.9
# Feature Type(Cont): continuous
# cw: 0.21511111111111067, wn: 0.4807111111111119 ---> 1.0 - (cw/wn) == 1.0 - 0.21511111111111067/0.4807111111111119
# cw: 0.08622222222222206, wn: 0.09404444444444426 ---> 1.0 - (cw/wn) == 1.0 - 0.08622222222222206/0.09404444444444426
# weighted_prob_node_left * w_i(left_node_data)): 0.6933333333333327 * 0.55251479289941 = 0.38307692307692387
# weighted_prob_node_right * w_i(right_node_data)): 0.30666666666666637 * 0.08317580340264641 = 0.02550724637681154
# column_index: 2, value: 5.0
# Feature Type(Cont): continuous
# cw: 0.22142222222222177, wn: 0.5184000000000011 ---> 1.0 - (cw/wn) == 1.0 - 0.22142222222222177/0.5184000000000011
# cw: 0.07475555555555542, wn: 0.07839999999999986 ---> 1.0 - (cw/wn) == 1.0 - 0.07475555555555542/0.07839999999999986
# weighted_prob_node_left * w_i(left_node_data)): 0.7199999999999993 * 0.5728737997256533 = 0.41246913580247
# weighted_prob_node_right * w_i(right_node_data)): 0.27999999999999975 * 0.046485260770975034 = 0.013015873015872998
# column_index: 2, value: 5.1
# Feature Type(Cont): continuous
# cw: 0.23359999999999956, wn: 0.5980444444444462 ---> 1.0 - (cw/wn) == 1.0 - 0.23359999999999956/0.5980444444444462
# cw: 0.051377777777777696, wn: 0.051377777777777696 ---> 1.0 - (cw/wn) == 1.0 - 0.051377777777777696/0.051377777777777696
# weighted_prob_node_left * w_i(left_node_data)): 0.7733333333333327 * 0.6093935790725346 = 0.471264367816093
# weighted_prob_node_right * w_i(right_node_data)): 0.2266666666666665 * 0.0 = 0.0
# column_index: 2, value: 5.2
# Feature Type(Cont): continuous
# cw: 0.23662222222222176, wn: 0.6188444444444463 ---> 1.0 - (cw/wn) == 1.0 - 0.23662222222222176/0.6188444444444463
# cw: 0.045511111111111044, wn: 0.045511111111111044 ---> 1.0 - (cw/wn) == 1.0 - 0.045511111111111044/0.045511111111111044
# weighted_prob_node_left * w_i(left_node_data)): 0.786666666666666 * 0.6176386095949459 = 0.48587570621469034
# weighted_prob_node_right * w_i(right_node_data)): 0.21333333333333318 * 0.0 = 0.0
# column_index: 2, value: 5.3
# Feature Type(Cont): continuous
# cw: 0.23999999999999955, wn: 0.640000000000002 ---> 1.0 - (cw/wn) == 1.0 - 0.23999999999999955/0.640000000000002
# cw: 0.03999999999999995, wn: 0.03999999999999995 ---> 1.0 - (cw/wn) == 1.0 - 0.03999999999999995/0.03999999999999995
# weighted_prob_node_left * w_i(left_node_data)): 0.7999999999999993 * 0.6250000000000019 = 0.500000000000001
# weighted_prob_node_right * w_i(right_node_data)): 0.19999999999999987 * 0.0 = 0.0
# column_index: 2, value: 5.4
# Feature Type(Cont): continuous
# cw: 0.24373333333333286, wn: 0.6615111111111133 ---> 1.0 - (cw/wn) == 1.0 - 0.24373333333333286/0.6615111111111133
# cw: 0.03484444444444441, wn: 0.03484444444444441 ---> 1.0 - (cw/wn) == 1.0 - 0.03484444444444441/0.03484444444444441
# weighted_prob_node_left * w_i(left_node_data)): 0.8133333333333326 * 0.6315506584251565 = 0.5136612021857935
# weighted_prob_node_right * w_i(right_node_data)): 0.18666666666666656 * 0.0 = 0.0
# column_index: 2, value: 5.5
# Feature Type(Cont): continuous
# cw: 0.24999999999999953, wn: 0.6944444444444469 ---> 1.0 - (cw/wn) == 1.0 - 0.24999999999999953/0.6944444444444469
# cw: 0.027777777777777755, wn: 0.027777777777777755 ---> 1.0 - (cw/wn) == 1.0 - 0.027777777777777755/0.027777777777777755
# weighted_prob_node_left * w_i(left_node_data)): 0.8333333333333326 * 0.6400000000000019 = 0.5333333333333344
# weighted_prob_node_right * w_i(right_node_data)): 0.1666666666666666 * 0.0 = 0.0
# column_index: 2, value: 5.6
# Feature Type(Cont): continuous
# cw: 0.2649333333333328, wn: 0.7627111111111141 ---> 1.0 - (cw/wn) == 1.0 - 0.2649333333333328/0.7627111111111141
# cw: 0.016044444444444448, wn: 0.016044444444444448 ---> 1.0 - (cw/wn) == 1.0 - 0.016044444444444448/0.016044444444444448
# weighted_prob_node_left * w_i(left_node_data)): 0.8733333333333325 * 0.6526426198939477 = 0.5699745547073805
# weighted_prob_node_right * w_i(right_node_data)): 0.12666666666666668 * 0.0 = 0.0
# column_index: 2, value: 5.7
# Feature Type(Cont): continuous
# cw: 0.27359999999999945, wn: 0.7980444444444478 ---> 1.0 - (cw/wn) == 1.0 - 0.27359999999999945/0.7980444444444478
# cw: 0.01137777777777778, wn: 0.01137777777777778 ---> 1.0 - (cw/wn) == 1.0 - 0.01137777777777778/0.01137777777777778
# weighted_prob_node_left * w_i(left_node_data)): 0.8933333333333324 * 0.6571619514368477 = 0.5870646766169167
# weighted_prob_node_right * w_i(right_node_data)): 0.10666666666666667 * 0.0 = 0.0
# column_index: 2, value: 5.8
# Feature Type(Cont): continuous
# cw: 0.28306666666666613, wn: 0.8341777777777815 ---> 1.0 - (cw/wn) == 1.0 - 0.28306666666666613/0.8341777777777815
# cw: 0.007511111111111112, wn: 0.007511111111111112 ---> 1.0 - (cw/wn) == 1.0 - 0.007511111111111112/0.007511111111111112
# weighted_prob_node_left * w_i(left_node_data)): 0.9133333333333324 * 0.6606638606212393 = 0.6034063260340646
# weighted_prob_node_right * w_i(right_node_data)): 0.08666666666666667 * 0.0 = 0.0
# column_index: 2, value: 5.9
# Feature Type(Cont): continuous
# cw: 0.28982222222222165, wn: 0.858711111111115 ---> 1.0 - (cw/wn) == 1.0 - 0.28982222222222165/0.858711111111115
# cw: 0.005377777777777778, wn: 0.005377777777777778 ---> 1.0 - (cw/wn) == 1.0 - 0.005377777777777778/0.005377777777777778
# weighted_prob_node_left * w_i(left_node_data)): 0.9266666666666658 * 0.6624915894622454 = 0.6139088729016802
# weighted_prob_node_right * w_i(right_node_data)): 0.07333333333333333 * 0.0 = 0.0
# column_index: 2, value: 6.0
# Feature Type(Cont): continuous
# cw: 0.2969333333333327, wn: 0.883600000000004 ---> 1.0 - (cw/wn) == 1.0 - 0.2969333333333327/0.883600000000004
# cw: 0.0036000000000000008, wn: 0.0036000000000000008 ---> 1.0 - (cw/wn) == 1.0 - 0.0036000000000000008/0.0036000000000000008
# weighted_prob_node_left * w_i(left_node_data)): 0.9399999999999991 * 0.6639505055077735 = 0.6241134751773064
# weighted_prob_node_right * w_i(right_node_data)): 0.060000000000000005 * 0.0 = 0.0
# column_index: 2, value: 6.1
# Feature Type(Cont): continuous
# cw: 0.308266666666666, wn: 0.9216000000000044 ---> 1.0 - (cw/wn) == 1.0 - 0.308266666666666/0.9216000000000044
# cw: 0.0016, wn: 0.0016 ---> 1.0 - (cw/wn) == 1.0 - 0.0016/0.0016
# weighted_prob_node_left * w_i(left_node_data)): 0.9599999999999991 * 0.6655092592592615 = 0.6388888888888904
# weighted_prob_node_right * w_i(right_node_data)): 0.04 * 0.0 = 0.0
# column_index: 2, value: 6.3
# Feature Type(Cont): continuous
# cw: 0.3122222222222216, wn: 0.934444444444449 ---> 1.0 - (cw/wn) == 1.0 - 0.3122222222222216/0.934444444444449
# cw: 0.0011111111111111111, wn: 0.0011111111111111111 ---> 1.0 - (cw/wn) == 1.0 - 0.0011111111111111111/0.0011111111111111111
# weighted_prob_node_left * w_i(left_node_data)): 0.9666666666666657 * 0.6658739595719404 = 0.6436781609195418
# weighted_prob_node_right * w_i(right_node_data)): 0.03333333333333333 * 0.0 = 0.0
# column_index: 2, value: 6.4
# Feature Type(Cont): continuous
# cw: 0.31626666666666603, wn: 0.9473777777777824 ---> 1.0 - (cw/wn) == 1.0 - 0.31626666666666603/0.9473777777777824
# cw: 0.0007111111111111113, wn: 0.0007111111111111113 ---> 1.0 - (cw/wn) == 1.0 - 0.0007111111111111113/0.0007111111111111113
# weighted_prob_node_left * w_i(left_node_data)): 0.9733333333333323 * 0.6661662600863225 = 0.6484018264840199
# weighted_prob_node_right * w_i(right_node_data)): 0.02666666666666667 * 0.0 = 0.0
# column_index: 2, value: 6.6
# Feature Type(Cont): continuous
# cw: 0.32039999999999935, wn: 0.9604000000000048 ---> 1.0 - (cw/wn) == 1.0 - 0.32039999999999935/0.9604000000000048
# cw: 0.0004, wn: 0.0004 ---> 1.0 - (cw/wn) == 1.0 - 0.0004/0.0004
# weighted_prob_node_left * w_i(left_node_data)): 0.979999999999999 * 0.6663890045814267 = 0.6530612244897975
# weighted_prob_node_right * w_i(right_node_data)): 0.02 * 0.0 = 0.0
# column_index: 2, value: 6.7
# Feature Type(Cont): continuous
# cw: 0.32893333333333263, wn: 0.9867111111111161 ---> 1.0 - (cw/wn) == 1.0 - 0.32893333333333263/0.9867111111111161
# cw: 4.444444444444445e-05, wn: 4.444444444444445e-05 ---> 1.0 - (cw/wn) == 1.0 - 4.444444444444445e-05/4.444444444444445e-05
# weighted_prob_node_left * w_i(left_node_data)): 0.9933333333333323 * 0.6666366379892821 = 0.6621923937360195
# weighted_prob_node_right * w_i(right_node_data)): 0.006666666666666667 * 0.0 = 0.0
# column_index: 2, value: 6.9
# Feature Type(Cont): continuous
# cw: 0.33333333333333265, wn: 1.0000000000000049 ---> 1.0 - (cw/wn) == 1.0 - 0.33333333333333265/1.0000000000000049
# COLUMN 3
# column_index: 3, value: 0.1
# Feature Type(Cont): continuous
# cw: 0.0016, wn: 0.0016 ---> 1.0 - (cw/wn) == 1.0 - 0.0016/0.0016
# cw: 0.308266666666666, wn: 0.9216000000000044 ---> 1.0 - (cw/wn) == 1.0 - 0.308266666666666/0.9216000000000044
# weighted_prob_node_left * w_i(left_node_data)): 0.04 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.9599999999999991 * 0.6655092592592615 = 0.6388888888888904
# column_index: 3, value: 0.2
# Feature Type(Cont): continuous
# cw: 0.051377777777777696, wn: 0.051377777777777696 ---> 1.0 - (cw/wn) == 1.0 - 0.051377777777777696/0.051377777777777696
# cw: 0.23359999999999953, wn: 0.5980444444444462 ---> 1.0 - (cw/wn) == 1.0 - 0.23359999999999953/0.5980444444444462
# weighted_prob_node_left * w_i(left_node_data)): 0.2266666666666665 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.7733333333333327 * 0.6093935790725347 = 0.47126436781609304
# column_index: 3, value: 0.3
# Feature Type(Cont): continuous
# cw: 0.07471111111111098, wn: 0.07471111111111098 ---> 1.0 - (cw/wn) == 1.0 - 0.07471111111111098/0.07471111111111098
# cw: 0.22582222222222176, wn: 0.5280444444444456 ---> 1.0 - (cw/wn) == 1.0 - 0.22582222222222176/0.5280444444444456
# weighted_prob_node_left * w_i(left_node_data)): 0.2733333333333331 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.7266666666666659 * 0.5723423954212628 = 0.4159021406727838
# column_index: 3, value: 0.4
# Feature Type(Cont): continuous
# cw: 0.1023999999999998, wn: 0.1023999999999998 ---> 1.0 - (cw/wn) == 1.0 - 0.1023999999999998/0.1023999999999998
# cw: 0.22239999999999954, wn: 0.46240000000000064 ---> 1.0 - (cw/wn) == 1.0 - 0.22239999999999954/0.46240000000000064
# weighted_prob_node_left * w_i(left_node_data)): 0.3199999999999997 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.6799999999999993 * 0.5190311418685138 = 0.35294117647058904
# column_index: 3, value: 0.5
# Feature Type(Cont): continuous
# cw: 0.1067111111111109, wn: 0.1067111111111109 ---> 1.0 - (cw/wn) == 1.0 - 0.1067111111111109/0.1067111111111109
# cw: 0.22226666666666622, wn: 0.4533777777777784 ---> 1.0 - (cw/wn) == 1.0 - 0.22226666666666622/0.4533777777777784
# weighted_prob_node_left * w_i(left_node_data)): 0.3266666666666663 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.6733333333333327 * 0.5097539456916005 = 0.343234323432344
# column_index: 3, value: 0.6
# Feature Type(Cont): continuous
# cw: 0.11111111111111088, wn: 0.11111111111111088 ---> 1.0 - (cw/wn) == 1.0 - 0.11111111111111088/0.11111111111111088
# cw: 0.22222222222222177, wn: 0.444444444444445 ---> 1.0 - (cw/wn) == 1.0 - 0.22222222222222177/0.444444444444445
# weighted_prob_node_left * w_i(left_node_data)): 0.333333333333333 * 0.0 = 0.0
# weighted_prob_node_right * w_i(right_node_data)): 0.666666666666666 * 0.5000000000000016 = 0.33333333333333404
# column_index: 3, value: 1.0
# Feature Type(Cont): continuous
# cw: 0.11328888888888866, wn: 0.14439999999999967 ---> 1.0 - (cw/wn) == 1.0 - 0.11328888888888866/0.14439999999999967
# cw: 0.1932888888888885, wn: 0.38440000000000013 ---> 1.0 - (cw/wn) == 1.0 - 0.1932888888888885/0.38440000000000013
# weighted_prob_node_left * w_i(left_node_data)): 0.37999999999999967 * 0.21545090797168331 = 0.0818713450292396
# weighted_prob_node_right * w_i(right_node_data)): 0.6199999999999994 * 0.49716730257833386 = 0.3082437275985667
# column_index: 3, value: 1.1
# Feature Type(Cont): continuous
# cw: 0.11555555555555533, wn: 0.15999999999999961 ---> 1.0 - (cw/wn) == 1.0 - 0.11555555555555533/0.15999999999999961
# cw: 0.18222222222222187, wn: 0.36 ---> 1.0 - (cw/wn) == 1.0 - 0.18222222222222187/0.36
# weighted_prob_node_left * w_i(left_node_data)): 0.39999999999999963 * 0.27777777777777746 = 0.11111111111111088
# weighted_prob_node_right * w_i(right_node_data)): 0.5999999999999994 * 0.49382716049382813 = 0.2962962962962966
# column_index: 3, value: 1.2
# Feature Type(Cont): continuous
# cw: 0.12111111111111089, wn: 0.18777777777777732 ---> 1.0 - (cw/wn) == 1.0 - 0.12111111111111089/0.18777777777777732
# cw: 0.16555555555555523, wn: 0.32111111111111085 ---> 1.0 - (cw/wn) == 1.0 - 0.16555555555555523/0.32111111111111085
# weighted_prob_node_left * w_i(left_node_data)): 0.433333333333333 * 0.35502958579881616 = 0.15384615384615355
# weighted_prob_node_right * w_i(right_node_data)): 0.5666666666666661 * 0.4844290657439452 = 0.27450980392156865
# column_index: 3, value: 1.3
# Feature Type(Cont): continuous
# cw: 0.14595555555555528, wn: 0.2703999999999994 ---> 1.0 - (cw/wn) == 1.0 - 0.14595555555555528/0.2703999999999994
# cw: 0.13262222222222197, wn: 0.23039999999999938 ---> 1.0 - (cw/wn) == 1.0 - 0.13262222222222197/0.23039999999999938
# weighted_prob_node_left * w_i(left_node_data)): 0.5199999999999996 * 0.4602235371466139 = 0.23931623931623902
# weighted_prob_node_right * w_i(right_node_data)): 0.47999999999999965 * 0.42438271604938227 = 0.20370370370370333
# column_index: 3, value: 1.4
# Feature Type(Cont): continuous
# cw: 0.1655999999999997, wn: 0.3287111111111109 ---> 1.0 - (cw/wn) == 1.0 - 0.1655999999999997/0.3287111111111109
# cw: 0.1167111111111109, wn: 0.18204444444444398 ---> 1.0 - (cw/wn) == 1.0 - 0.1167111111111109/0.18204444444444398
# weighted_prob_node_left * w_i(left_node_data)): 0.5733333333333328 * 0.4962141698215258 = 0.2844961240310078
# weighted_prob_node_right * w_i(right_node_data)): 0.4266666666666663 * 0.35888671874999956 = 0.15312499999999968
# column_index: 3, value: 1.5
# Feature Type(Cont): continuous
# cw: 0.20151111111111072, wn: 0.42684444444444486 ---> 1.0 - (cw/wn) == 1.0 - 0.20151111111111072/0.42684444444444486
# cw: 0.09928888888888869, wn: 0.12017777777777752 ---> 1.0 - (cw/wn) == 1.0 - 0.09928888888888869/0.12017777777777752
# weighted_prob_node_left * w_i(left_node_data)): 0.6533333333333327 * 0.5279050395668485 = 0.344897959183674
# weighted_prob_node_right * w_i(right_node_data)): 0.34666666666666635 * 0.17381656804733714 = 0.06025641025641015
# column_index: 3, value: 1.6
# Feature Type(Cont): continuous
# cw: 0.2142222222222218, wn: 0.46240000000000064 ---> 1.0 - (cw/wn) == 1.0 - 0.2142222222222218/0.46240000000000064
# cw: 0.09422222222222204, wn: 0.1023999999999998 ---> 1.0 - (cw/wn) == 1.0 - 0.09422222222222204/0.1023999999999998
# weighted_prob_node_left * w_i(left_node_data)): 0.6799999999999993 * 0.5367166474432926 = 0.3649673202614386
# weighted_prob_node_right * w_i(right_node_data)): 0.3199999999999997 * 0.07986111111111105 = 0.02555555555555551
# column_index: 3, value: 1.7
# Feature Type(Cont): continuous
# cw: 0.2189333333333329, wn: 0.4807111111111119 ---> 1.0 - (cw/wn) == 1.0 - 0.2189333333333329/0.4807111111111119
# cw: 0.09004444444444427, wn: 0.09404444444444426 ---> 1.0 - (cw/wn) == 1.0 - 0.09004444444444427/0.09404444444444426
# weighted_prob_node_left * w_i(left_node_data)): 0.6933333333333326 * 0.5445636094674573 = 0.37756410256410333
# weighted_prob_node_right * w_i(right_node_data)): 0.30666666666666637 * 0.042533081285444196 = 0.01304347826086954
# column_index: 3, value: 1.8
# Feature Type(Cont): continuous
# cw: 0.23359999999999956, wn: 0.5980444444444462 ---> 1.0 - (cw/wn) == 1.0 - 0.23359999999999956/0.5980444444444462
# cw: 0.051377777777777696, wn: 0.051377777777777696 ---> 1.0 - (cw/wn) == 1.0 - 0.051377777777777696/0.051377777777777696
# weighted_prob_node_left * w_i(left_node_data)): 0.7733333333333327 * 0.6093935790725346 = 0.471264367816093
# weighted_prob_node_right * w_i(right_node_data)): 0.2266666666666665 * 0.0 = 0.0
# column_index: 3, value: 1.9
# Feature Type(Cont): continuous
# cw: 0.24182222222222177, wn: 0.6507111111111132 ---> 1.0 - (cw/wn) == 1.0 - 0.24182222222222177/0.6507111111111132
# cw: 0.03737777777777773, wn: 0.03737777777777773 ---> 1.0 - (cw/wn) == 1.0 - 0.03737777777777773/0.03737777777777773
# weighted_prob_node_left * w_i(left_node_data)): 0.806666666666666 * 0.628372378935867 = 0.5068870523415989
# weighted_prob_node_right * w_i(right_node_data)): 0.19333333333333322 * 0.0 = 0.0
# column_index: 3, value: 2.0
# Feature Type(Cont): continuous
# cw: 0.25462222222222175, wn: 0.7168444444444471 ---> 1.0 - (cw/wn) == 1.0 - 0.25462222222222175/0.7168444444444471
# cw: 0.0235111111111111, wn: 0.0235111111111111 ---> 1.0 - (cw/wn) == 1.0 - 0.0235111111111111/0.0235111111111111
# weighted_prob_node_left * w_i(left_node_data)): 0.8466666666666659 * 0.6448012896025812 = 0.5459317585301849
# weighted_prob_node_right * w_i(right_node_data)): 0.1533333333333333 * 0.0 = 0.0
# column_index: 3, value: 2.1
# Feature Type(Cont): continuous
# cw: 0.2706222222222217, wn: 0.786177777777781 ---> 1.0 - (cw/wn) == 1.0 - 0.2706222222222217/0.786177777777781
# cw: 0.012844444444444447, wn: 0.012844444444444447 ---> 1.0 - (cw/wn) == 1.0 - 0.012844444444444447/0.012844444444444447
# weighted_prob_node_left * w_i(left_node_data)): 0.8866666666666658 * 0.6557747752840769 = 0.5814536340852143
# weighted_prob_node_right * w_i(right_node_data)): 0.11333333333333334 * 0.0 = 0.0
# column_index: 3, value: 2.2
# Feature Type(Cont): continuous
# cw: 0.27982222222222164, wn: 0.822044444444448 ---> 1.0 - (cw/wn) == 1.0 - 0.27982222222222164/0.822044444444448
# cw: 0.008711111111111112, wn: 0.008711111111111112 ---> 1.0 - (cw/wn) == 1.0 - 0.008711111111111112/0.008711111111111112
# weighted_prob_node_left * w_i(left_node_data)): 0.9066666666666657 * 0.6596020761245697 = 0.5980392156862759
# weighted_prob_node_right * w_i(right_node_data)): 0.09333333333333334 * 0.0 = 0.0
# column_index: 3, value: 2.3
# Feature Type(Cont): continuous
# cw: 0.308266666666666, wn: 0.9216000000000044 ---> 1.0 - (cw/wn) == 1.0 - 0.308266666666666/0.9216000000000044
# cw: 0.0016, wn: 0.0016 ---> 1.0 - (cw/wn) == 1.0 - 0.0016/0.0016
# weighted_prob_node_left * w_i(left_node_data)): 0.9599999999999991 * 0.6655092592592615 = 0.6388888888888904
# weighted_prob_node_right * w_i(right_node_data)): 0.04 * 0.0 = 0.0
# column_index: 3, value: 2.4
# Feature Type(Cont): continuous
# cw: 0.32039999999999935, wn: 0.9604000000000048 ---> 1.0 - (cw/wn) == 1.0 - 0.32039999999999935/0.9604000000000048
# cw: 0.0004, wn: 0.0004 ---> 1.0 - (cw/wn) == 1.0 - 0.0004/0.0004
# weighted_prob_node_left * w_i(left_node_data)): 0.979999999999999 * 0.6663890045814267 = 0.6530612244897975
# weighted_prob_node_right * w_i(right_node_data)): 0.02 * 0.0 = 0.0
# column_index: 3, value: 2.5
# Feature Type(Cont): continuous
# cw: 0.33333333333333265, wn: 1.0000000000000049 ---> 1.0 - (cw/wn) == 1.0 - 0.33333333333333265/1.0000000000000049

# %%
split_column_index
# Out:
# 3

# %%
split_value
# Out:
# 0.6

# %%
# Out:
# ['continuous', 'continuous', 'continuous', 'continuous', 'categorical']

# %%
    label_column = data[:, -2]
    data_sample_weight =  data[:, -1]
    _, value_indexes, counts = np.unique(label_column, return_counts=True, return_index=True)
    # Get summed weights for each class
    class_weights = np.array([np.take(data_sample_weight, np.where(label_column == label_column[value_index])[0]).sum() for value_index in value_indexes])

    weighted_classes = counts * class_weights
    normalized_weighted_classes = weighted_classes / sum(weighted_classes)
    #return 1.0 - (np.sum(counts**2) / np.sum(class_weights)**2)
    return 1.0 - sum(normalized_weighted_classes**2)

# %%
x = np.array([2, 2, 0, 0])
x1 = np.array([2, 2, 2, 0])
x2 = np.array([2, 2, 2, 2])

# %%
wt = np.full(len(x), np.divide(0.5, len(x)))
wt1 = np.array([0.2, 0.2, 0.05, 0.05])

# %%
def gineee(x, w):
    label_column = x
    data_sample_weight =  w
    _, value_indexes, counts = np.unique(label_column, return_counts=True, return_index=True)
    class_weights = np.array([np.take(data_sample_weight, np.where(label_column == label_column[value_index])[0]).sum() for value_index in value_indexes])
    cw = np.sum(class_weights**2)
    wn = np.sum(data_sample_weight)**2
    gini = 1.0 - (cw/wn)
    print(counts)
    print(class_weights)
    return gini

# %%
gineee(x2, wt)
# Out:
# [4]
# [0.5]
# 0.0

# %%
wt
# Out:
# array([0.125, 0.125, 0.125, 0.125])
